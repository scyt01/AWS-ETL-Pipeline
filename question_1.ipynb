# %% [markdown]
# # Installation

# %%
pip install boto3
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.11/site-packages (1.34.162)
# Requirement already satisfied: botocore<1.35.0,>=1.34.162 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.34.162)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.10.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.162->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.162->boto3) (1.26.19)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.162->boto3) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard~=2.19.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.11/site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install keras
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.11/site-packages (3.6.0)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.11/site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (from keras) (3.13.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras) (0.14.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.11/site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.11/site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow h5py
# Out:
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (3.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard~=2.19.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /opt/conda/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import boto3
from io import StringIO
from io import BytesIO

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn.ensemble import IsolationForest
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras.models import Model
from keras.layers import Conv1D, LSTM, Dense, Flatten, Dropout, BatchNormalization, Input, Reshape
from sklearn.preprocessing import MinMaxScaler
from keras.optimizers import Adam
# Out:
# 2025-03-21 06:02:33.360374: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-21 06:02:33.364531: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-21 06:02:33.376640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742536953.396940   12946 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742536953.403475   12946 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742536953.419172   12946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742536953.419186   12946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742536953.419188   12946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742536953.419190   12946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-21 06:02:33.424141: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Reading the cleaned data from S3

# %%
s3 = boto3.client('s3')
bucket_name = "459-team4-project"
object_key = "clean-data/dataset_merged.csv"

obj = s3.get_object(Bucket=bucket_name, Key=object_key)
df = pd.read_csv(obj['Body'])

print(df.head())
# Out:
#        LCLid         day  energy_median  energy_mean  energy_max  \
# 0  MAC004707  2013-01-01         0.1775     0.282438       1.195
# 1  MAC004707  2013-01-02         0.2310     0.316854       1.224
# 2  MAC004707  2013-01-03         0.2190     0.284896       0.914
# 3  MAC004707  2013-01-04         0.3255     0.339187       0.673
# 4  MAC004707  2013-01-05         0.2940     0.298854       0.660
#
#    energy_count  energy_std  energy_sum  energy_min stdorToU    Acorn  \
# 0            48    0.211532      13.557       0.113      Std  ACORN-E
# 1            48    0.220660      15.209       0.113      Std  ACORN-E
# 2            48    0.163766      13.675       0.119      Std  ACORN-E
# 3            48    0.184414      16.281       0.100      Std  ACORN-E
# 4            48    0.165935      14.345       0.096      Std  ACORN-E
#
#   Acorn_grouped      file
# 0      Affluent  block_22
# 1      Affluent  block_22
# 2      Affluent  block_22
# 3      Affluent  block_22
# 4      Affluent  block_22

# %%
# Check for null values
df.isnull().sum()
# Out:
# LCLid            0
# day              0
# energy_median    0
# energy_mean      0
# energy_max       0
# energy_count     0
# energy_std       0
# energy_sum       0
# energy_min       0
# stdorToU         0
# Acorn            0
# Acorn_grouped    0
# file             0
# dtype: int64

# %%
# Check for total rows count
# About 23k plus extra rows were removed as compared to the one on Google Drive
df.count()
# Out:
# LCLid            1915031
# day              1915031
# energy_median    1915031
# energy_mean      1915031
# energy_max       1915031
# energy_count     1915031
# energy_std       1915031
# energy_sum       1915031
# energy_min       1915031
# stdorToU         1915031
# Acorn            1915031
# Acorn_grouped    1915031
# file             1915031
# dtype: int64

# %%
# Checking if a "LCLid" exist
df[df['LCLid'] == 'mac004553']
# Out:
# Empty DataFrame
# Columns: [LCLid, day, energy_median, energy_mean, energy_max, energy_count, energy_std, energy_sum, energy_min, stdorToU, Acorn, Acorn_grouped, file]
# Index: []

# %% [markdown]
# # Using EDA (3Q + 3 IQR) to remove extreme outliers (as it affects model training and k means clustering)

# %%
# List of the unique acorn values
unique_acorn_values = [
    "ACORN-",
    "ACORN-A",
    "ACORN-B",
    "ACORN-C",
    "ACORN-D",
    "ACORN-E",
    "ACORN-F",
    "ACORN-G",
    "ACORN-H",
    "ACORN-I",
    "ACORN-J",
    "ACORN-K",
    "ACORN-L",
    "ACORN-M",
    "ACORN-N",
    "ACORN-O",
    "ACORN-P",
    "ACORN-Q",
    "ACORN-U"
]

# Dictionary to store outliers for each acorn group
outliers_dict = {}

for acorn in unique_acorn_values:
    # Filter df for the current acorn group
    acorn_data = df[df['Acorn'] == acorn]

    # Compute the average energy_sum per LCLid
    acorn_avg_energy = acorn_data.groupby('LCLid')['energy_sum'].mean()

    # Compute Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = np.percentile(acorn_avg_energy, 25)
    Q3 = np.percentile(acorn_avg_energy, 75)

    # Compute IQR (Interquartile Range)
    IQR = Q3 - Q1

    # Compute upper bound for outliers (Q3 + 3 * IQR)
    upper_bound = Q3 + 3 * IQR

    # Identify outlier LCLid values
    outliers = acorn_avg_energy[acorn_avg_energy > upper_bound].index.tolist()

    # Store results
    outliers_dict[acorn] = outliers

# Print outlier LCLid for each acorn group
for acorn, outliers in outliers_dict.items():
    print(f"acorn Group {acorn} - Outlier LCLid(s): {outliers}")
# Out:
# acorn Group ACORN- - Outlier LCLid(s): []
# acorn Group ACORN-A - Outlier LCLid(s): ['MAC004319']
# acorn Group ACORN-B - Outlier LCLid(s): []
# acorn Group ACORN-C - Outlier LCLid(s): []
# acorn Group ACORN-D - Outlier LCLid(s): []
# acorn Group ACORN-E - Outlier LCLid(s): []
# acorn Group ACORN-F - Outlier LCLid(s): []
# acorn Group ACORN-G - Outlier LCLid(s): []
# acorn Group ACORN-H - Outlier LCLid(s): []
# acorn Group ACORN-I - Outlier LCLid(s): []
# acorn Group ACORN-J - Outlier LCLid(s): []
# acorn Group ACORN-K - Outlier LCLid(s): []
# acorn Group ACORN-L - Outlier LCLid(s): []
# acorn Group ACORN-M - Outlier LCLid(s): []
# acorn Group ACORN-N - Outlier LCLid(s): []
# acorn Group ACORN-O - Outlier LCLid(s): []
# acorn Group ACORN-P - Outlier LCLid(s): ['MAC005340', 'MAC005402']
# acorn Group ACORN-Q - Outlier LCLid(s): ['MAC003594', 'MAC004395']
# acorn Group ACORN-U - Outlier LCLid(s): []

# %%
extreme_outliers = []

for acorn, outliers in outliers_dict.items():
    if len(outliers) >= 1:
        for extreme_outlier_LCLid in outliers:
            extreme_outliers.append(extreme_outlier_LCLid)

print(extreme_outliers)
# Out:
# ['MAC004319', 'MAC005340', 'MAC005402', 'MAC003594', 'MAC004395']

# %%
# Removing extreme outliers to form Dataset A
dataset_A = df[~df["LCLid"].isin(extreme_outliers)]

# %% [markdown]
# # K-means clustering with Dataset A, output is k_means_outliers

# %%
# Preprocessing: Normalize the data (assuming the columns you want to use for clustering)
features = ['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']
scaler = StandardScaler()
dataset_A[features] = scaler.fit_transform(dataset_A[features])

# Define function to cluster data per LCLid
def cluster_per_LCLid(data):
    LCLid_clusters = {}
    k_means_outliers = []
    LCLid_outlier_percentages = {}

    # Loop through each unique LCLid
    for LCLid in data['LCLid'].unique():
        # Create a copy of the subset for each LCLid to avoid modification on a view
        LCLid_data = data[data['LCLid'] == LCLid].copy()

        # Apply KMeans clustering for each LCLid
        kmeans = KMeans(n_clusters=2)  # Cluster of 2 is chosen - 1 for winter months, and another for non-winter months
        LCLid_data['cluster'] = kmeans.fit_predict(LCLid_data[features])

        # Calculate the distance of each point to its assigned cluster center
        distances = kmeans.transform(LCLid_data[features])
        min_distances = np.min(distances, axis=1)

        # Set a threshold for identifying outliers (e.g., points that are farther than 1.5 times the average distance)
        threshold = 1.5 * np.mean(min_distances)

        # Flag points that are far from the centroids (outliers)
        outliers = LCLid_data[min_distances > threshold]

        # Calculate the percentage of outliers
        outlier_percentage = len(outliers) / len(LCLid_data) * 100

        # Record the percentage of outliers for the current LCLid
        LCLid_outlier_percentages[LCLid] = outlier_percentage

        # If more than 20% of the points are outliers, flag as fraud
        if outlier_percentage > 20:
            k_means_outliers.append(LCLid)

    return k_means_outliers, LCLid_outlier_percentages

# Apply the function
k_means_outliers, LCLid_outlier_percentages = cluster_per_LCLid(dataset_A)

# Print the results
print("Fraudulent LCLids:", k_means_outliers)
print("Percentage of Outliers for each LCLid:")
for LCLid, outlier_percentage in LCLid_outlier_percentages.items():
    print(f"LCLid {LCLid}: {outlier_percentage:.2f}% outliers")
# Out:
# Fraudulent LCLids: ['MAC000874', 'MAC002304', 'MAC003648', 'MAC004730', 'MAC004852', 'MAC002963', 'MAC004317', 'MAC000956', 'MAC003629', 'MAC001269', 'MAC000621', 'MAC003764', 'MAC005092', 'MAC005162', 'MAC004811', 'MAC005279', 'MAC001176', 'MAC004064', 'MAC005180', 'MAC001340', 'MAC000019', 'MAC004846', 'MAC004751', 'MAC002710', 'MAC004595', 'MAC004433', 'MAC000036', 'MAC000960', 'MAC001039', 'MAC003994', 'MAC004552', 'MAC002881', 'MAC000607', 'MAC005008', 'MAC005386', 'MAC003789', 'MAC004102', 'MAC005250', 'MAC001495', 'MAC004634', 'MAC002863', 'MAC000664', 'MAC000891', 'MAC000916', 'MAC004803', 'MAC000657', 'MAC000153', 'MAC002765', 'MAC002624', 'MAC004983', 'MAC003005', 'MAC002324', 'MAC002146', 'MAC002382', 'MAC001512', 'MAC004646', 'MAC000729', 'MAC003054', 'MAC003919', 'MAC005055', 'MAC003791', 'MAC002843', 'MAC002925', 'MAC002651', 'MAC002642', 'MAC002972', 'MAC005442', 'MAC005214', 'MAC004506', 'MAC002611', 'MAC001499', 'MAC000501', 'MAC003884', 'MAC003006', 'MAC004191', 'MAC002157', 'MAC004748', 'MAC001898', 'MAC003906', 'MAC001378', 'MAC002050', 'MAC005495', 'MAC001967', 'MAC000018', 'MAC000865', 'MAC004445', 'MAC000065', 'MAC003056', 'MAC004884', 'MAC002672', 'MAC005259', 'MAC004227', 'MAC003206', 'MAC005094', 'MAC001296', 'MAC002241', 'MAC003846', 'MAC001312', 'MAC002490', 'MAC000229', 'MAC001126', 'MAC000418', 'MAC000520', 'MAC001451', 'MAC000813', 'MAC001945', 'MAC000491', 'MAC004720', 'MAC000128', 'MAC000704', 'MAC000677', 'MAC001823', 'MAC000392', 'MAC003202', 'MAC003183', 'MAC003456', 'MAC002898', 'MAC004365', 'MAC001870', 'MAC004204', 'MAC004436', 'MAC003365', 'MAC001782', 'MAC004604', 'MAC001311', 'MAC003038', 'MAC004481', 'MAC001403', 'MAC002911', 'MAC002004', 'MAC002251', 'MAC005404', 'MAC005277', 'MAC005355', 'MAC001321', 'MAC002875', 'MAC000134', 'MAC001347', 'MAC004681', 'MAC001277', 'MAC003398', 'MAC004697', 'MAC000605', 'MAC003517', 'MAC001836', 'MAC003479', 'MAC002862', 'MAC004624', 'MAC005301', 'MAC001488', 'MAC005411', 'MAC005157', 'MAC002926', 'MAC001629', 'MAC001313', 'MAC003518', 'MAC004735', 'MAC002329', 'MAC001216', 'MAC003363', 'MAC004872', 'MAC003772', 'MAC003221', 'MAC000394', 'MAC001921', 'MAC003634', 'MAC004816', 'MAC000767', 'MAC002867', 'MAC002754', 'MAC004655', 'MAC005286', 'MAC001649', 'MAC004680', 'MAC002427', 'MAC004430', 'MAC002842', 'MAC004897', 'MAC004283', 'MAC005068', 'MAC005528', 'MAC000083', 'MAC005557', 'MAC002042', 'MAC001838', 'MAC005443', 'MAC004949', 'MAC005312', 'MAC000524', 'MAC003422', 'MAC005083', 'MAC001025', 'MAC005368', 'MAC004454', 'MAC000032', 'MAC002946', 'MAC001392', 'MAC003943', 'MAC004383', 'MAC004432', 'MAC000600', 'MAC004136', 'MAC001456', 'MAC003781', 'MAC003602', 'MAC000185', 'MAC005519', 'MAC003001', 'MAC000814', 'MAC000828', 'MAC001550', 'MAC005376', 'MAC001078', 'MAC001777', 'MAC001476', 'MAC001290', 'MAC004903', 'MAC000415', 'MAC004783', 'MAC003658', 'MAC003037', 'MAC000102', 'MAC005336', 'MAC003680', 'MAC001897', 'MAC005080', 'MAC002018', 'MAC002801', 'MAC001798', 'MAC000643', 'MAC005328', 'MAC002885', 'MAC000590', 'MAC004421', 'MAC004434', 'MAC001064', 'MAC003970', 'MAC003285', 'MAC002671', 'MAC001644', 'MAC001552', 'MAC002252', 'MAC001705', 'MAC004975', 'MAC002160', 'MAC002141', 'MAC005537', 'MAC002217', 'MAC003881', 'MAC002374', 'MAC000429', 'MAC004468', 'MAC004482', 'MAC005310', 'MAC001989', 'MAC003419', 'MAC000252', 'MAC000160', 'MAC002314', 'MAC000879', 'MAC001010', 'MAC003752', 'MAC001710', 'MAC003328', 'MAC004223', 'MAC000819', 'MAC001801', 'MAC001920', 'MAC005102', 'MAC003424', 'MAC000136', 'MAC004563', 'MAC004954', 'MAC001697', 'MAC003779', 'MAC000331', 'MAC001470', 'MAC005391', 'MAC002317', 'MAC002247', 'MAC004970', 'MAC004958', 'MAC001600', 'MAC000109', 'MAC005333', 'MAC004612', 'MAC005226', 'MAC005308', 'MAC003617', 'MAC003578', 'MAC004666', 'MAC000833', 'MAC005227', 'MAC001853', 'MAC003353', 'MAC000297', 'MAC000569', 'MAC002202', 'MAC000223', 'MAC001722', 'MAC004991', 'MAC001013', 'MAC001558', 'MAC003098', 'MAC004558', 'MAC001808', 'M ...
# Percentage of Outliers for each LCLid:
# LCLid MAC004707: 9.04% outliers
# LCLid MAC001480: 17.81% outliers
# LCLid MAC001484: 14.52% outliers
# LCLid MAC001675: 7.95% outliers
# LCLid MAC003112: 13.42% outliers
# LCLid MAC005125: 15.34% outliers
# LCLid MAC004095: 10.96% outliers
# LCLid MAC004423: 15.11% outliers
# LCLid MAC002830: 16.16% outliers
# LCLid MAC002397: 10.96% outliers
# LCLid MAC005431: 18.08% outliers
# LCLid MAC000867: 12.05% outliers
# LCLid MAC001868: 13.97% outliers
# LCLid MAC000054: 9.32% outliers
# LCLid MAC001154: 11.23% outliers
# LCLid MAC001896: 15.89% outliers
# LCLid MAC000291: 12.05% outliers
# LCLid MAC002556: 16.16% outliers
# LCLid MAC002752: 16.71% outliers
# LCLid MAC005326: 19.45% outliers
# LCLid MAC000874: 22.74% outliers
# LCLid MAC001019: 15.66% outliers
# LCLid MAC003951: 12.60% outliers
# LCLid MAC003965: 11.51% outliers
# LCLid MAC000041: 13.97% outliers
# LCLid MAC001049: 3.84% outliers
# LCLid MAC004555: 9.59% outliers
# LCLid MAC001524: 15.89% outliers
# LCLid MAC003437: 10.41% outliers
# LCLid MAC000091: 15.89% outliers
# LCLid MAC002304: 23.84% outliers
# LCLid MAC005128: 7.40% outliers
# LCLid MAC000827: 10.41% outliers
# LCLid MAC001505: 12.33% outliers
# LCLid MAC002440: 10.68% outliers
# LCLid MAC003833: 12.33% outliers
# LCLid MAC003648: 20.55% outliers
# LCLid MAC004239: 18.36% outliers
# LCLid MAC000188: 12.60% outliers
# LCLid MAC000563: 8.22% outliers
# LCLid MAC003587: 15.34% outliers
# LCLid MAC001651: 12.88% outliers
# LCLid MAC004280: 11.51% outliers
# LCLid MAC000962: 8.49% outliers
# LCLid MAC004050: 9.04% outliers
# LCLid MAC001062: 16.44% outliers
# LCLid MAC003161: 10.00% outliers
# LCLid MAC003637: 6.58% outliers
# LCLid MAC004889: 15.62% outliers
# LCLid MAC000510: 15.62% outliers
# LCLid MAC004294: 13.42% outliers
# LCLid MAC001463: 12.88% outliers
# LCLid MAC003451: 13.70% outliers
# LCLid MAC004613: 12.88% outliers
# LCLid MAC004730: 21.37% outliers
# LCLid MAC001551: 11.78% outliers
# LCLid MAC003704: 12.60% outliers
# LCLid MAC000919: 7.12% outliers
# LCLid MAC002986: 12.33% outliers
# LCLid MAC004804: 9.86% outliers
# LCLid MAC002393: 5.21% outliers
# LCLid MAC001052: 9.86% outliers
# LCLid MAC002996: 12.60% outliers
# LCLid MAC001121: 7.99% outliers
# LCLid MAC000576: 10.41% outliers
# LCLid MAC001122: 17.54% outliers
# LCLid MAC001247: 4.11% outliers
# LCLid MAC000360: 10.96% outliers
# LCLid MAC001138: 7.67% outliers
# LCLid MAC001158: 12.42% outliers
# LCLid MAC005161: 16.16% outliers
# LCLid MAC000444: 7.76% outliers
# LCLid MAC000518: 11.78% outliers
# LCLid MAC001707: 19.45% outliers
# LCLid MAC003164: 9.32% outliers
# LCLid MAC002660: 10.68% outliers
# LCLid MAC005482: 14.25% outliers
# LCLid MAC004852: 25.75% outliers
# LCLid MAC000534: 10.59% outliers
# LCLid MAC005056: 12.46% outliers
# LCLid MAC000690: 14.01% outliers
# LCLid MAC004342: 19.45% outliers
# LCLid MAC004579: 7.40% outliers
# LCLid MAC004694: 16.71% outliers
# LCLid MAC001119: 13.15% outliers
# LCLid MAC002147: 12.33% outliers
# LCLid MAC005085: 15.34% outliers
# LCLid MAC003528: 15.07% outliers
# LCLid MAC000832: 12.05% outliers
# LCLid MAC002368: 13.97% outliers
# LCLid MAC002963: 23.29% outliers
# LCLid MAC005240: 14.79% outliers
# LCLid MAC000367: 15.89% outliers
# LCLid MAC000905: 18.63% outliers
# LCLid MAC000940: 12.04% outliers
# LCLid MAC004312: 13.97% outliers
# LCLid MAC001902: 19.76% outliers
# LCLid MAC000573: 13.97% outliers
# LCLid MAC003351: 10.19% outliers
# LCLid MAC000551: 19.45% outliers
# LCLid MAC004805: 6.32% outliers
# LCLid MAC005551: 17.26% outliers
# LCLid MAC003130: 18.63% outliers
# LCLid MAC000527: 9.32% outliers
# LCLid MAC001031: 15.62% outliers
# LCLid MAC004317: 21.64% outliers
# LCLid MAC004586: 10.14% outliers
# LCLid MAC004695: 11.78% outliers
# LCLid MAC003086: 15.34% outliers
# LCLid MAC002246: 9.04% outliers
# LCLid MAC003899: 9.86% outliers
# LCLid MAC004494: 12.60% outliers
# LCLid MAC002465: 20.00% outliers
# LCLid MAC005451: 10.14% outliers
# LCLid MAC000950: 14.52% outliers
# LCLid MAC001022: 14.25% outliers
# LCLid MAC001260: 9.32% outliers
# LCLid MAC000230: 10.41% outliers
# LCLid MAC003050: 10.14% outliers
# LCLid MAC005067: 9.32% outliers
# LCLid MAC005123: 8.22% outliers
# LCLid MAC001231: 16.88% outliers
# LCLid MAC003809: 15.34% outliers
# LCLid MAC000374: 6.03% outliers
# LCLid MAC004521: 17.53% outliers
# LCLid MAC004526: 13.15% outliers
# LCLid MAC005147: 15.07% outliers
# LCLid MAC001274: 11.78% outliers
# LCLid MAC001720: 16.16% outliers
# LCLid MAC001737: 12.60% outliers
# LCLid MAC005284: 12.88% outliers
# LCLid MAC000466: 11.78% outliers
# LCLid MAC003189: 14.25% outliers
# LCLid MAC003192: 15.62% outliers
# LCLid MAC004042: 13.15% outliers
# LCLid MAC005529: 9.04% outliers
# LCLid MAC002670: 15.68% outliers
# LCLid MAC004030: 15.62% outliers
# LCLid MAC004794: 13.15% outliers
# LCLid MAC005053: 17.81% outliers
# LCLid MAC000486: 8.25% outliers
# LCLid MAC000507: 13.42% outliers
# LCLid MAC000718: 9.48% outliers
# LCLid MAC002728: 18.36% outliers
# LCLid MAC004084: 9.04% outliers
# LCLid MAC000226: 10.96% outliers
# LCLid MAC004197: 13.70% outliers
# LCLid MAC004253: 13.15% outliers
# LCLid MAC004582: 19.73% outliers
# LCLid MAC004671: 13.15% outliers
# LCLid MAC003209: 9.32% outliers
# LCLid MAC004951: 10.96% outliers
# LCLid MAC000956: 21.92% outliers
# LCLid MAC003960: 11.23% outliers
# LCLid MAC000720: 9.59% outliers
# LCLid MAC000842: 16.44% outliers
# LCLid MAC005071: 16.16% outliers
# LCLid MAC000575: 6.58% outliers
# LCLid MAC003099: 8.77% outliers
# LCLid MAC000854: 12.33% outliers
# LCLid MAC003768: 13.70% outliers
# LCLid MAC004144: 11.23% outliers
# LCLid MAC000217: 7.67% outliers
# LCLid MAC004299: 9.65% outliers
# LCLid MAC005146: 18.90% outliers
# LCLid MAC000526: 13.97% outliers
# LCLid MAC000562: 11.51% outliers
# LCLid MAC001279: 15.07% outliers
# LCLid MAC005189: 18.11% outliers
# LCLid MAC005190: 9.32% outliers
# LCLid MAC002548: 6.30% outliers
# LCLid MAC002549: 10.99% outliers
# LCLid MAC004756: 15.79% outliers
# LCLid MAC001282: 9.59% outliers
# LCLid MAC004920: 11.78% outliers
# LCLid MAC004132: 12.88% outliers
# LCLid MAC004181: 13.42% outliers
# LCLid MAC004571: 12.33% outliers
# LCLid MAC004656: 12.60% outliers
# LCLid MAC003581: 8.22% outliers
# LCLid MAC003753: 10.96% outliers
# LCLid MAC004321: 6.58% outliers
# LCLid MAC004391: 12.33% outliers
# LCLid MAC002122: 10.96% outliers
# LCLid MAC004606: 12.88% outliers
# LCLid MAC004696: 13.15% outliers
# LCLid MAC002554: 15.07% outliers
# LCLid MAC000558: 9.64% outliers
# LCLid MAC001100: 16.71% outliers
# LCLid MAC000405: 12.05% outliers
# LCLid MAC004048: 16.16% outliers
# LCLid MAC000903: 14.79% outliers
# LCLid MAC005477: 13.15% outliers
# LCLid MAC003629: 21.92% outliers
# LCLid MAC003644: 12.60% outliers
# LCLid MAC000243: 9.92% outliers
# LCLid MAC004170: 12.05% outliers
# LCLid MAC005535: 9.32% outliers
# LCLid MAC004758: 8.77% outliers
# LCLid MAC004779: 17.81% outliers
# LCLid MAC004857: 13.70% outliers
# LCLid MAC003064: 13.15% outliers
# LCLid MAC005052: 12.33% outliers
# LCLid MAC000696: 13.70% outliers
# LCLid MAC001048: 9.04% outliers
# LCLid MAC001190: 9.59% outliers
# LCLid MAC001269: 25.21% outliers
# LCLid MAC004041: 17.81% outliers
# LCLid MAC004212: 9.86% outliers
# LCLid MAC000131: 10.41% outliers
# LCLid MAC003506: 9.59% outliers
# LCLid MAC004556: 8.49% outliers
# LCLid MAC001409: 17.13% outliers
# LCLid MAC002076: 11.78% outliers
# LCLid MAC004286: 13.70% outliers
# LCLid MAC004114: 11.51% outliers
# LCLid MAC005448: 14.52% outliers
# LCLid MAC002938: 13.15% outliers
# LCLid MAC001570: 10.14% outliers
# LCLid MAC002061: 10.14% outliers
# LCLid MAC002183: 11.02% outliers
# LCLid MAC001173: 14.79% outliers
# LCLid MAC000858: 7.95% outliers
# LCLid MAC000887: 11.51% outliers
# LCLid MAC000579: 8.77% outliers
# LCLid MAC001106: 5.48% outliers
# LCLid MAC001399: 12.33% outliers
# LCLid MAC000368: 11.23% outliers
# LCLid MAC004245: 10.68% outliers
# LCLid MAC004290: 9.04% outliers
# LCLid MAC001455: 20.00% outliers
# LCLid MAC001038: 7.40% outliers
# LCLid MAC004601: 12.88% outliers
# LCLid MAC003808: 14.25% outliers
# LCLid MAC003865: 20.00% outliers
# LCLid MAC003616: 14.25% outliers
# LCLid MAC002395: 14.79% outliers
# LCLid MAC000958: 17.53% outliers
# LCLid MAC000621: 22.47% outliers
# LCLid MAC003764: 25.75% outliers
# LCLid MAC000053: 10.41% outliers
# LCLid MAC001635: 10.68% outliers
# LCLid MAC002044: 6.58% outliers
# LCLid MAC005092: 25.00% outliers
# LCLid MAC001357: 12.05% outliers
# LCLid MAC001618: 14.52% outliers
# LCLid MAC003969: 10.96% outliers
# LCLid MAC005162: 21.37% outliers
# LCLid MAC005432: 16.44% outliers
# LCLid MAC001800: 9.86% outliers
# LCLid MAC000279: 15.34% outliers
# LCLid MAC001021: 9.86% outliers
# LCLid MAC004811: 23.56% outliers
# LCLid MAC000556: 17.53% outliers
# LCLid MAC001041: 13.42% outliers
# LCLid MAC004003: 15.07% outliers
# LCLid MAC004343: 6.58% outliers
# LCLid MAC000530: 16.44% outliers
# LCLid MAC000539: 13.15% outliers
# LCLid MAC004201: 7.12% outliers
# LCLid MAC004226: 13.38% outliers
# LCLid MAC004736: 12.05% outliers
# LCLid MAC003205: 11.23% outliers
# LCLid MAC003246: 14.91% outliers
# LCLid MAC005525: 13.70% outliers
# LCLid MAC001847: 17.26% outliers
# LCLid MAC002376: 10.68% outliers
# LCLid MAC001027: 7.12% outliers
# LCLid MAC001081: 18.90% outliers
# LCLid MAC000055: 18.63% outliers
# LCLid MAC005549: 8.77% outliers
# LCLid MAC000859: 19.18% outliers
# LCLid MAC000580: 14.52% outliers
# LCLid MAC001204: 18.36% outliers
# LCLid MAC003102: 16.10% outliers
# LCLid MAC003812: 16.44% outliers
# LCLid MAC004288: 10.41% outliers
# LCLid MAC004478: 12.33% outliers
# LCLid MAC001889: 11.17% outliers
# LCLid MAC005279: 23.29% outliers
# LCLid MAC004311: 12.16% outliers
# LCLid MAC005205: 13.35% outliers
# LCLid MAC004781: 3.84% outliers
# LCLid MAC004786: 10.41% outliers
# LCLid MAC000242: 9.59% outliers
# LCLid MAC000253: 11.23% outliers
# LCLid MAC003141: 14.52% outliers
# LCLid MAC003362: 9.59% outliers
# LCLid MAC000362: 15.89% outliers
# LCLid MAC001050: 12.60% outliers
# LCLid MAC004339: 13.42% outliers
# LCLid MAC000860: 9.86% outliers
# LCLid MAC002188: 10.41% outliers
# LCLid MAC004931: 7.12% outliers
# LCLid MAC005546: 13.70% outliers
# LCLid MAC004035: 6.30% outliers
# LCLid MAC000660: 12.88% outliers
# LCLid MAC004077: 20.00% outliers
# LCLid MAC000599: 10.47% outliers
# LCLid MAC001176: 23.56% outliers
# LCLid MAC001193: 7.95% outliers
# LCLid MAC000936: 18.08% outliers
# LCLid MAC004118: 15.07% outliers
# LCLid MAC004303: 9.52% outliers
# LCLid MAC005204: 12.05% outliers
# LCLid MAC003443: 9.32% outliers
# LCLid MAC005323: 15.07% outliers
# LCLid MAC000042: 15.89% outliers
# LCLid MAC003060: 11.51% outliers
# LCLid MAC004064: 26.52% outliers
# LCLid MAC004022: 12.88% outliers
# LCLid MAC004298: 16.71% outliers
# LCLid MAC004237: 16.44% outliers
# LCLid MAC000228: 11.78% outliers
# LCLid MAC004702: 13.97% outliers
# LCLid MAC000937: 15.89% outliers
# LCLid MAC003074: 5.17% outliers
# LCLid MAC002086: 13.42% outliers
# LCLid MAC001152: 12.05% outliers
# LCLid MAC000215: 7.67% outliers
# LCLid MAC004483: 7.49% outliers
# LCLid MAC000438: 9.35% outliers
# LCLid MAC002144: 15.89% outliers
# LCLid MAC000407: 11.78% outliers
# LCLid MAC003998: 10.96% outliers
# LCLid MAC004135: 7.12% outliers
# LCLid MAC000717: 12.60% outliers
# LCLid MAC001275: 18.08% outliers
# LCLid MAC001298: 8.49% outliers
# LCLid MAC000740: 14.52% outliers
# LCLid MAC004220: 9.86% outliers
# LCLid MAC000235: 12.88% outliers
# LCLid MAC001485: 19.45% outliers
# LCLid MAC004265: 8.49% outliers
# LCLid MAC003722: 12.88% outliers
# LCLid MAC003897: 13.70% outliers
# LCLid MAC004440: 17.81% outliers
# LCLid MAC005035: 12.33% outliers
# LCLid MAC004001: 11.51% outliers
# LCLid MAC001467: 8.49% outliers
# LCLid MAC001888: 16.16% outliers
# LCLid MAC001125: 11.51% outliers
# LCLid MAC000061: 3.29% outliers
# LCLid MAC000622: 11.23% outliers
# LCLid MAC001168: 13.42% outliers
# LCLid MAC003097: 11.78% outliers
# LCLid MAC003430: 8.77% outliers
# LCLid MAC003866: 13.15% outliers
# LCLid MAC000049: 13.15% outliers
# LCLid MAC001117: 10.96% outliers
# LCLid MAC004229: 15.34% outliers
# LCLid MAC003172: 7.67% outliers
# LCLid MAC002542: 17.81% outliers
# LCLid MAC005179: 9.86% outliers
# LCLid MAC000992: 13.42% outliers
# LCLid MAC003312: 8.49% outliers
# LCLid MAC004235: 10.14% outliers
# LCLid MAC000011: 16.99% outliers
# LCLid MAC000913: 14.25% outliers
# LCLid MAC003638: 10.68% outliers
# LCLid MAC002449: 11.66% outliers
# LCLid MAC002864: 12.60% outliers
# LCLid MAC000834: 19.45% outliers
# LCLid MAC001848: 12.60% outliers
# LCLid MAC005107: 12.60% outliers
# LCLid MAC001507: 11.78% outliers
# LCLid MAC003547: 10.41% outliers
# LCLid MAC005450: 8.77% outliers
# LCLid MAC001134: 12.28% outliers
# LCLid MAC000724: 13.15% outliers
# LCLid MAC003415: 10.96% outliers
# LCLid MAC005329: 16.71% outliers
# LCLid MAC003152: 16.16% outliers
# LCLid MAC003971: 16.99% outliers
# LCLid MAC000273: 10.96% outliers
# LCLid MAC001289: 13.15% outliers
# LCLid MAC002786: 9.32% outliers
# LCLid MAC003059: 14.79% outliers
# LCLid MAC000047: 6.85% outliers
# LCLid MAC001334: 13.97% outliers
# LCLid MAC004185: 10.14% outliers
# LCLid MAC000222: 20.00% outliers
# LCLid MAC000234: 15.62% outliers
# LCLid MAC004706: 10.96% outliers
# LCLid MAC003026: 12.88% outliers
# LCLid MAC004098: 13.42% outliers
# LCLid MAC000649: 15.89% outliers
# LCLid MAC002429: 9.59% outliers
# LCLid MAC001042: 16.16% outliers
# LCLid MAC004546: 15.07% outliers
# LCLid MAC001813: 16.71% outliers
# LCLid MAC002090: 15.07% outliers
# LCLid MAC003155: 15.47% outliers
# LCLid MAC001462: 6.30% outliers
# LCLid MAC003440: 10.14% outliers
# LCLid MAC001056: 13.42% outliers
# LCLid MAC000210: 6.58% outliers
# LCLid MAC000502: 14.79% outliers
# LCLid MAC000516: 8.77% outliers
# LCLid MAC000546: 14.04% outliers
# LCLid MAC001299: 19.18% outliers
# LCLid MAC001702: 7.67% outliers
# LCLid MAC005180: 21.37% outliers
# LCLid MAC000731: 15.62% outliers
# LCLid MAC004793: 13.97% outliers
# LCLid MAC002543: 10.96% outliers
# LCLid MAC004292: 4.12% outliers
# LCLid MAC005538: 18.90% outliers
# LCLid MAC004769: 17.79% outliers
# LCLid MAC004944: 11.78% outliers
# LCLid MAC001094: 15.89% outliers
# LCLid MAC002716: 15.62% outliers
# LCLid MAC001340: 29.86% outliers
# LCLid MAC000010: 10.96% outliers
# LCLid MAC003682: 10.14% outliers
# LCLid MAC002886: 11.78% outliers
# LCLid MAC002176: 14.25% outliers
# LCLid MAC002389: 12.05% outliers
# LCLid MAC002500: 10.68% outliers
# LCLid MAC000951: 15.28% outliers
# LCLid MAC000990: 12.33% outliers
# LCLid MAC000852: 12.33% outliers
# LCLid MAC004603: 13.70% outliers
# LCLid MAC004719: 6.30% outliers
# LCLid MAC000056: 13.42% outliers
# LCLid MAC000627: 11.23% outliers
# LCLid MAC001153: 8.22% outliers
# LCLid MAC005022: 16.30% outliers
# LCLid MAC000446: 13.46% outliers
# LCLid MAC000028: 11.83% outliers
# LCLid MAC001163: 10.96% outliers
# LCLid MAC001905: 13.15% outliers
# LCLid MAC005292: 12.88% outliers
# LCLid MAC003785: 13.15% outliers
# LCLid MAC004640: 11.51% outliers
# LCLid MAC002137: 10.68% outliers
# LCLid MAC002884: 16.16% outliers
# LCLid MAC004790: 10.96% outliers
# LCLid MAC003378: 14.25% outliers
# LCLid MAC000161: 15.49% outliers
# LCLid MAC000189: 16.16% outliers
# LCLid MAC004116: 16.16% outliers
# LCLid MAC000536: 13.70% outliers
# LCLid MAC003893: 10.14% outliers
# LCLid MAC004257: 9.78% outliers
# LCLid MAC004701: 14.25% outliers
# LCLid MAC004727: 10.68% outliers
# LCLid MAC000043: 12.60% outliers
# LCLid MAC001297: 14.52% outliers
# LCLid MAC004929: 11.23% outliers
# LCLid MAC000570: 8.22% outliers
# LCLid MAC001601: 13.70% outliers
# LCLid MAC002030: 10.41% outliers
# LCLid MAC002084: 8.49% outliers
# LCLid MAC002182: 14.79% outliers
# LCLid MAC001032: 15.62% outliers
# LCLid MAC002879: 18.90% outliers
# LCLid MAC000019: 20.82% outliers
# LCLid MAC001372: 5.48% outliers
# LCLid MAC001828: 17.53% outliers
# LCLid MAC000585: 17.81% outliers
# LCLid MAC001243: 8.31% outliers
# LCLid MAC001240: 9.59% outliers
# LCLid MAC001875: 20.00% outliers
# LCLid MAC001991: 7.95% outliers
# LCLid MAC001123: 9.04% outliers
# LCLid MAC000184: 12.50% outliers
# LCLid MAC004499: 8.22% outliers
# LCLid MAC001741: 11.23% outliers
# LCLid MAC005290: 17.81% outliers
# LCLid MAC001787: 8.49% outliers
# LCLid MAC004315: 12.60% outliers
# LCLid MAC004846: 24.56% outliers
# LCLid MAC000702: 13.97% outliers
# LCLid MAC001293: 13.97% outliers
# LCLid MAC005045: 12.33% outliers
# LCLid MAC004094: 14.25% outliers
# LCLid MAC004112: 15.89% outliers
# LCLid MAC004300: 12.60% outliers
# LCLid MAC004328: 9.59% outliers
# LCLid MAC003509: 14.25% outliers
# LCLid MAC000221: 8.49% outliers
# LCLid MAC004562: 11.23% outliers
# LCLid MAC000089: 16.44% outliers
# LCLid MAC000119: 10.41% outliers
# LCLid MAC000645: 13.97% outliers
# LCLid MAC001101: 19.45% outliers
# LCLid MAC002430: 15.89% outliers
# LCLid MAC001822: 16.44% outliers
# LCLid MAC003029: 10.14% outliers
# LCLid MAC000543: 16.71% outliers
# LCLid MAC001233: 12.88% outliers
# LCLid MAC003864: 19.45% outliers
# LCLid MAC004751: 20.55% outliers
# LCLid MAC005212: 12.33% outliers
# LCLid MAC000592: 10.14% outliers
# LCLid MAC003191: 20.00% outliers
# LCLid MAC004169: 9.04% outliers
# LCLid MAC005070: 16.99% outliers
# LCLid MAC005276: 19.45% outliers
# LCLid MAC000969: 13.70% outliers
# LCLid MAC004946: 17.81% outliers
# LCLid MAC002710: 21.10% outliers
# LCLid MAC004709: 15.62% outliers
# LCLid MAC000237: 12.43% outliers
# LCLid MAC004020: 10.68% outliers
# LCLid MAC004087: 13.70% outliers
# LCLid MAC001944: 16.44% outliers
# LCLid MAC004682: 13.15% outliers
# LCLid MAC003436: 13.97% outliers
# LCLid MAC003684: 7.95% outliers
# LCLid MAC004155: 5.21% outliers
# LCLid MAC005229: 11.51% outliers
# LCLid MAC001379: 11.51% outliers
# LCLid MAC005473: 12.60% outliers
# LCLid MAC001548: 12.33% outliers
# LCLid MAC001569: 9.32% outliers
# LCLid MAC000972: 10.14% outliers
# LCLid MAC001188: 10.41% outliers
# LCLid MAC001226: 17.81% outliers
# LCLid MAC003959: 13.97% outliers
# LCLid MAC000443: 12.33% outliers
# LCLid MAC001712: 14.75% outliers
# LCLid MAC000694: 10.96% outliers
# LCLid MAC003435: 11.78% outliers
# LCLid MAC003574: 12.05% outliers
# LCLid MAC003688: 16.16% outliers
# LCLid MAC004036: 19.73% outliers
# LCLid MAC004316: 12.91% outliers
# LCLid MAC004340: 10.68% outliers
# LCLid MAC005314: 12.60% outliers
# LCLid MAC004868: 11.23% outliers
# LCLid MAC004856: 12.60% outliers
# LCLid MAC005001: 10.14% outliers
# LCLid MAC005032: 14.52% outliers
# LCLid MAC004941: 11.51% outliers
# LCLid MAC000695: 15.98% outliers
# LCLid MAC003790: 18.08% outliers
# LCLid MAC004096: 9.86% outliers
# LCLid MAC000399: 15.53% outliers
# LCLid MAC000550: 15.62% outliers
# LCLid MAC004584: 10.68% outliers
# LCLid MAC004595: 23.56% outliers
# LCLid MAC004629: 15.34% outliers
# LCLid MAC004690: 11.23% outliers
# LCLid MAC002356: 12.60% outliers
# LCLid MAC002480: 10.41% outliers
# LCLid MAC002489: 8.49% outliers
# LCLid MAC000973: 13.97% outliers
# LCLid MAC003144: 12.60% outliers
# LCLid MAC001860: 9.32% outliers
# LCLid MAC005114: 11.23% outliers
# LCLid MAC000560: 7.67% outliers
# LCLid MAC001891: 12.33% outliers
# LCLid MAC000892: 20.00% outliers
# LCLid MAC003950: 16.71% outliers
# LCLid MAC005173: 9.59% outliers
# LCLid MAC000004: 8.49% outliers
# LCLid MAC000540: 14.86% outliers
# LCLid MAC001895: 17.26% outliers
# LCLid MAC000245: 8.22% outliers
# LCLid MAC004433: 20.49% outliers
# LCLid MAC004836: 12.60% outliers
# LCLid MAC004923: 6.03% outliers
# LCLid MAC000684: 16.44% outliers
# LCLid MAC004883: 13.33% outliers
# LCLid MAC004345: 15.62% outliers
# LCLid MAC004356: 15.89% outliers
# LCLid MAC005046: 13.70% outliers
# LCLid MAC001385: 9.04% outliers
# LCLid MAC002466: 9.32% outliers
# LCLid MAC000968: 12.05% outliers
# LCLid MAC001077: 10.14% outliers
# LCLid MAC003034: 10.41% outliers
# LCLid MAC002970: 12.33% outliers
# LCLid MAC003454: 11.23% outliers
# LCLid MAC001053: 19.18% outliers
# LCLid MAC004285: 11.78% outliers
# LCLid MAC004304: 11.78% outliers
# LCLid MAC001753: 15.34% outliers
# LCLid MAC005291: 13.42% outliers
# LCLid MAC003181: 13.97% outliers
# LCLid MAC003345: 8.85% outliers
# LCLid MAC003565: 7.95% outliers
# LCLid MAC002546: 16.99% outliers
# LCLid MAC005182: 7.95% outliers
# LCLid MAC005195: 10.96% outliers
# LCLid MAC005393: 15.89% outliers
# LCLid MAC004157: 4.38% outliers
# LCLid MAC004833: 14.79% outliers
# LCLid MAC000748: 14.52% outliers
# LCLid MAC001314: 12.60% outliers
# LCLid MAC000769: 18.63% outliers
# LCLid MAC004202: 13.15% outliers
# LCLid MAC000067: 14.79% outliers
# LCLid MAC004457: 9.04% outliers
# LCLid MAC005456: 7.10% outliers
# LCLid MAC000975: 11.78% outliers
# LCLid MAC001164: 10.41% outliers
# LCLid MAC002524: 9.67% outliers
# LCLid MAC003045: 12.33% outliers
# LCLid MAC001591: 12.33% outliers
# LCLid MAC003501: 12.88% outliers
# LCLid MAC003834: 13.70% outliers
# LCLid MAC004106: 6.85% outliers
# LCLid MAC004313: 14.52% outliers
# LCLid MAC000779: 16.71% outliers
# LCLid MAC005498: 15.34% outliers
# LCLid MAC002683: 14.25% outliers
# LCLid MAC003963: 8.49% outliers
# LCLid MAC004800: 11.51% outliers
# LCLid MAC004826: 12.33% outliers
# LCLid MAC004998: 8.49% outliers
# LCLid MAC004115: 14.25% outliers
# LCLid MAC001718: 11.78% outliers
# LCLid MAC004560: 14.89% outliers
# LCLid MAC003758: 12.33% outliers
# LCLid MAC003991: 12.88% outliers
# LCLid MAC001072: 9.59% outliers
# LCLid MAC005397: 15.07% outliers
# LCLid MAC000036: 20.27% outliers
# LCLid MAC000960: 21.05% outliers
# LCLid MAC001039: 20.55% outliers
# LCLid MAC000841: 16.16% outliers
# LCLid MAC001809: 11.78% outliers
# LCLid MAC001877: 8.77% outliers
# LCLid MAC002994: 8.22% outliers
# LCLid MAC005078: 10.14% outliers
# LCLid MAC002997: 13.42% outliers
# LCLid MAC001859: 12.88% outliers
# LCLid MAC004002: 12.05% outliers
# LCLid MAC000941: 10.96% outliers
# LCLid MAC001109: 16.16% outliers
# LCLid MAC004967: 9.59% outliers
# LCLid MAC001716: 6.03% outliers
# LCLid MAC004207: 13.70% outliers
# LCLid MAC004576: 13.15% outliers
# LCLid MAC002545: 10.12% outliers
# LCLid MAC002656: 14.52% outliers
# LCLid MAC000714: 19.18% outliers
# LCLid MAC004875: 14.79% outliers
# LCLid MAC004943: 8.22% outliers
# LCLid MAC001047: 8.77% outliers
# LCLid MAC003994: 20.55% outliers
# LCLid MAC004014: 13.15% outliers
# LCLid MAC000100: 9.59% outliers
# LCLid MAC001244: 9.86% outliers
# LCLid MAC003217: 6.58% outliers
# LCLid MAC005096: 9.32% outliers
# LCLid MAC004000: 12.60% outliers
# LCLid MAC002316: 7.12% outliers
# LCLid MAC004250: 18.08% outliers
# LCLid MAC001408: 10.96% outliers
# LCLid MAC001975: 12.88% outliers
# LCLid MAC004260: 7.67% outliers
# LCLid MAC000721: 9.32% outliers
# LCLid MAC000980: 11.73% outliers
# LCLid MAC003880: 13.70% outliers
# LCLid MAC005327: 16.99% outliers
# LCLid MAC000125: 13.15% outliers
# LCLid MAC003947: 9.32% outliers
# LCLid MAC004918: 11.23% outliers
# LCLid MAC004936: 10.68% outliers
# LCLid MAC000703: 13.97% outliers
# LCLid MAC004892: 13.15% outliers
# LCLid MAC002678: 11.51% outliers
# LCLid MAC003993: 18.63% outliers
# LCLid MAC004013: 9.04% outliers
# LCLid MAC004341: 9.32% outliers
# LCLid MAC000132: 12.33% outliers
# LCLid MAC004538: 13.11% outliers
# LCLid MAC004552: 21.10% outliers
# LCLid MAC004665: 19.73% outliers
# LCLid MAC001205: 17.53% outliers
# LCLid MAC003549: 10.96% outliers
# LCLid MAC005054: 12.88% outliers
# LCLid MAC001016: 11.78% outliers
# LCLid MAC004107: 10.14% outliers
# LCLid MAC004100: 18.90% outliers
# LCLid MAC001043: 10.96% outliers
# LCLid MAC002881: 22.47% outliers
# LCLid MAC004692: 10.41% outliers
# LCLid MAC001162: 13.42% outliers
# LCLid MAC003088: 10.68% outliers
# LCLid MAC001525: 6.30% outliers
# LCLid MAC004284: 15.44% outliers
# LCLid MAC000448: 15.34% outliers
# LCLid MAC003369: 11.33% outliers
# LCLid MAC005394: 14.25% outliers
# LCLid MAC004985: 16.16% outliers
# LCLid MAC004999: 13.42% outliers
# LCLid MAC005005: 10.14% outliers
# LCLid MAC000541: 18.08% outliers
# LCLid MAC000735: 10.19% outliers
# LCLid MAC000743: 11.51% outliers
# LCLid MAC000107: 10.96% outliers
# LCLid MAC002739: 12.60% outliers
# LCLid MAC001118: 12.88% outliers
# LCLid MAC003852: 14.25% outliers
# LCLid MAC000029: 14.52% outliers
# LCLid MAC002933: 9.86% outliers
# LCLid MAC002940: 17.81% outliers
# LCLid MAC003087: 14.52% outliers
# LCLid MAC003995: 15.89% outliers
# LCLid MAC001573: 11.81% outliers
# LCLid MAC002417: 10.68% outliers
# LCLid MAC000370: 12.88% outliers
# LCLid MAC001066: 6.85% outliers
# LCLid MAC002869: 16.99% outliers
# LCLid MAC000281: 15.62% outliers
# LCLid MAC001225: 12.05% outliers
# LCLid MAC001799: 4.38% outliers
# LCLid MAC003841: 6.85% outliers
# LCLid MAC003132: 9.32% outliers
# LCLid MAC003503: 16.16% outliers
# LCLid MAC005073: 15.34% outliers
# LCLid MAC005077: 14.98% outliers
# LCLid MAC004979: 12.05% outliers
# LCLid MAC001292: 12.05% outliers
# LCLid MAC003759: 11.23% outliers
# LCLid MAC003832: 6.85% outliers
# LCLid MAC000057: 10.41% outliers
# LCLid MAC000875: 9.59% outliers
# LCLid MAC001060: 13.42% outliers
# LCLid MAC001149: 13.70% outliers
# LCLid MAC004310: 8.77% outliers
# LCLid MAC004753: 12.05% outliers
# LCLid MAC004837: 9.04% outliers
# LCLid MAC005150: 17.26% outliers
# LCLid MAC001699: 11.51% outliers
# LCLid MAC005197: 15.89% outliers
# LCLid MAC001821: 16.71% outliers
# LCLid MAC002645: 14.79% outliers
# LCLid MAC005106: 10.14% outliers
# LCLid MAC005181: 10.14% outliers
# LCLid MAC000248: 7.12% outliers
# LCLid MAC000262: 14.79% outliers
# LCLid MAC004919: 7.40% outliers
# LCLid MAC004099: 8.22% outliers
# LCLid MAC001932: 12.88% outliers
# LCLid MAC004008: 10.41% outliers
# LCLid MAC000034: 18.90% outliers
# LCLid MAC001054: 10.96% outliers
# LCLid MAC002034: 12.60% outliers
# LCLid MAC002205: 15.07% outliers
# LCLid MAC000896: 11.78% outliers
# LCLid MAC001161: 5.87% outliers
# LCLid MAC000607: 21.54% outliers
# LCLid MAC003641: 14.25% outliers
# LCLid MAC002550: 7.40% outliers
# LCLid MAC004348: 11.51% outliers
# LCLid MAC005206: 19.45% outliers
# LCLid MAC005007: 14.52% outliers
# LCLid MAC005008: 21.64% outliers
# LCLid MAC000513: 17.26% outliers
# LCLid MAC000746: 8.49% outliers
# LCLid MAC001089: 5.75% outliers
# LCLid MAC000159: 14.25% outliers
# LCLid MAC004330: 13.42% outliers
# LCLid MAC004332: 16.44% outliers
# LCLid MAC000177: 11.78% outliers
# LCLid MAC003519: 13.97% outliers
# LCLid MAC004548: 15.26% outliers
# LCLid MAC004574: 17.53% outliers
# LCLid MAC004705: 12.60% outliers
# LCLid MAC004057: 20.00% outliers
# LCLid MAC003626: 18.90% outliers
# LCLid MAC001058: 11.78% outliers
# LCLid MAC002902: 15.62% outliers
# LCLid MAC005386: 22.74% outliers
# LCLid MAC005542: 11.51% outliers
# LCLid MAC003984: 17.81% outliers
# LCLid MAC000290: 10.68% outliers
# LCLid MAC001415: 12.33% outliers
# LCLid MAC000901: 9.59% outliers
# LCLid MAC001818: 12.60% outliers
# LCLid MAC002277: 12.33% outliers
# LCLid MAC000391: 9.04% outliers
# LCLid MAC001257: 15.62% outliers
# LCLid MAC000554: 14.88% outliers
# LCLid MAC001446: 6.03% outliers
# LCLid MAC001996: 13.42% outliers
# LCLid MAC000538: 11.51% outliers
# LCLid MAC001701: 18.36% outliers
# LCLid MAC003350: 13.97% outliers
# LCLid MAC000385: 11.23% outliers
# LCLid MAC000511: 15.89% outliers
# LCLid MAC003789: 23.01% outliers
# LCLid MAC004102: 20.82% outliers
# LCLid MAC004105: 13.97% outliers
# LCLid MAC002715: 12.60% outliers
# LCLid MAC003825: 11.78% outliers
# LCLid MAC004564: 11.23% outliers
# LCLid MAC004638: 12.88% outliers
# LCLid MAC002300: 11.78% outliers
# LCLid MAC004896: 10.38% outliers
# LCLid MAC001543: 14.52% outliers
# LCLid MAC005466: 14.25% outliers
# LCLid MAC000033: 8.77% outliers
# LCLid MAC003975: 10.41% outliers
# LCLid MAC004610: 12.33% outliers
# LCLid MAC000044: 14.25% outliers
# LCLid MAC000845: 14.25% outliers
# LCLid MAC001090: 9.86% outliers
# LCLid MAC002998: 9.59% outliers
# LCLid MAC001272: 12.88% outliers
# LCLid MAC000918: 18.08% outliers
# LCLid MAC004124: 11.05% outliers
# LCLid MAC005250: 26.03% outliers
# LCLid MAC005507: 13.70% outliers
# LCLid MAC004722: 10.68% outliers
# LCLid MAC001495: 22.19% outliers
# LCLid MAC003997: 12.88% outliers
# LCLid MAC003999: 15.03% outliers
# LCLid MAC004854: 9.30% outliers
# LCLid MAC004995: 13.26% outliers
# LCLid MAC003070: 16.16% outliers
# LCLid MAC003168: 14.79% outliers
# LCLid MAC004898: 8.77% outliers
# LCLid MAC004934: 14.79% outliers
# LCLid MAC001035: 6.58% outliers
# LCLid MAC000152: 6.85% outliers
# LCLid MAC000180: 11.78% outliers
# LCLid MAC004581: 19.73% outliers
# LCLid MAC004634: 22.19% outliers
# LCLid MAC003177: 10.96% outliers
# LCLid MAC003372: 8.49% outliers
# LCLid MAC002863: 22.19% outliers
# LCLid MAC002451: 12.30% outliers
# LCLid MAC002460: 9.86% outliers
# LCLid MAC002487: 19.45% outliers
# LCLid MAC000664: 25.48% outliers
# LCLid MAC000364: 7.40% outliers
# LCLid MAC001497: 7.95% outliers
# LCLid MAC003754: 8.22% outliers
# LCLid MAC003986: 12.33% outliers
# LCLid MAC001111: 18.08% outliers
# LCLid MAC004301: 14.79% outliers
# LCLid MAC004492: 8.49% outliers
# LCLid MAC001754: 12.88% outliers
# LCLid MAC003455: 16.44% outliers
# LCLid MAC000572: 14.79% outliers
# LCLid MAC002622: 14.25% outliers
# LCLid MAC005315: 15.62% outliers
# LCLid MAC000996: 15.62% outliers
# LCLid MAC004858: 10.14% outliers
# LCLid MAC000269: 4.66% outliers
# LCLid MAC000542: 9.04% outliers
# LCLid MAC004693: 10.96% outliers
# LCLid MAC004289: 11.51% outliers
# LCLid MAC004308: 12.05% outliers
# LCLid MAC004203: 13.15% outliers
# LCLid MAC004553: 6.30% outliers
# LCLid MAC001816: 17.53% outliers
# LCLid MAC004309: 8.52% outliers
# LCLid MAC004359: 17.53% outliers
# LCLid MAC005508: 12.88% outliers
# LCLid MAC001254: 9.04% outliers
# LCLid MAC004559: 18.08% outliers
# LCLid MAC005438: 6.85% outliers
# LCLid MAC005441: 11.23% outliers
# LCLid MAC000035: 18.08% outliers
# LCLid MAC001001: 7.67% outliers
# LCLid MAC002232: 14.25% outliers
# LCLid MAC004508: 18.08% outliers
# LCLid MAC004631: 14.29% outliers
# LCLid MAC002927: 16.99% outliers
# LCLid MAC000571: 5.75% outliers
# LCLid MAC001207: 18.58% outliers
# LCLid MAC001115: 10.53% outliers
# LCLid MAC003665: 9.86% outliers
# LCLid MAC000211: 16.44% outliers
# LCLid MAC000634: 10.14% outliers
# LCLid MAC004296: 16.71% outliers
# LCLid MAC004768: 13.42% outliers
# LCLid MAC002681: 11.78% outliers
# LCLid MAC000917: 8.52% outliers
# LCLid MAC004307: 15.34% outliers
# LCLid MAC004784: 13.15% outliers
# LCLid MAC004798: 17.13% outliers
# LCLid MAC004806: 8.22% outliers
# LCLid MAC004849: 10.96% outliers
# LCLid MAC004996: 19.18% outliers
# LCLid MAC000891: 21.37% outliers
# LCLid MAC003134: 10.68% outliers
# LCLid MAC001051: 15.08% outliers
# LCLid MAC004015: 14.79% outliers
# LCLid MAC004254: 11.51% outliers
# LCLid MAC004565: 11.78% outliers
# LCLid MAC001607: 9.04% outliers
# LCLid MAC003215: 14.76% outliers
# LCLid MAC005467: 9.78% outliers
# LCLid MAC005471: 10.68% outliers
# LCLid MAC001011: 11.45% outliers
# LCLid MAC001082: 3.51% outliers
# LCLid MAC000123: 8.22% outliers
# LCLid MAC004845: 10.14% outliers
# LCLid MAC000763: 10.14% outliers
# LCLid MAC003564: 14.25% outliers
# LCLid MAC004023: 9.59% outliers
# LCLid MAC004867: 13.97% outliers
# LCLid MAC004759: 11.78% outliers
# LCLid MAC000268: 9.04% outliers
# LCLid MAC003138: 18.90% outliers
# LCLid MAC004818: 17.53% outliers
# LCLid MAC003747: 14.79% outliers
# LCLid MAC004744: 16.71% outliers
# LCLid MAC004038: 8.49% outliers
# LCLid MAC000433: 7.12% outliers
# LCLid MAC002242: 13.15% outliers
# LCLid MAC004952: 11.51% outliers
# LCLid MAC000946: 14.34% outliers
# LCLid MAC005048: 11.78% outliers
# LCLid MAC002979: 11.78% outliers
# LCLid MAC001615: 18.08% outliers
# LCLid MAC005481: 16.16% outliers
# LCLid MAC000964: 15.89% outliers
# LCLid MAC001073: 16.44% outliers
# LCLid MAC004320: 15.89% outliers
# LCLid MAC002412: 16.99% outliers
# LCLid MAC001230: 16.16% outliers
# LCLid MAC000916: 20.55% outliers
# LCLid MAC001099: 6.30% outliers
# LCLid MAC001148: 13.97% outliers
# LCLid MAC001725: 14.79% outliers
# LCLid MAC001745: 9.86% outliers
# LCLid MAC000803: 9.32% outliers
# LCLid MAC004778: 17.81% outliers
# LCLid MAC004797: 11.11% outliers
# LCLid MAC004803: 24.66% outliers
# LCLid MAC004819: 11.51% outliers
# LCLid MAC001067: 12.60% outliers
# LCLid MAC001037: 12.60% outliers
# LCLid MAC001083: 10.68% outliers
# LCLid MAC001213: 9.04% outliers
# LCLid MAC003777: 14.79% outliers
# LCLid MAC002283: 10.68% outliers
# LCLid MAC004699: 15.89% outliers
# LCLid MAC002369: 14.79% outliers
# LCLid MAC000965: 13.42% outliers
# LCLid MAC003439: 9.86% outliers
# LCLid MAC000383: 11.23% outliers
# LCLid MAC005388: 13.70% outliers
# LCLid MAC001535: 10.96% outliers
# LCLid MAC000977: 6.35% outliers
# LCLid MAC001104: 15.62% outliers
# LCLid MAC003028: 18.34% outliers
# LCLid MAC000657: 22.47% outliers
# LCLid MAC001218: 11.23% outliers
# LCLid MAC001266: 12.33% outliers
# LCLid MAC000372: 15.07% outliers
# LCLid MAC001144: 9.86% outliers
# LCLid MAC004152: 14.52% outliers
# LCLid MAC003967: 11.51% outliers
# LCLid MAC004523: 11.78% outliers
# LCLid MAC004774: 11.51% outliers
# LCLid MAC004775: 9.04% outliers
# LCLid MAC000711: 13.08% outliers
# LCLid MAC004894: 11.78% outliers
# LCLid MAC004935: 13.97% outliers
# LCLid MAC001086: 9.86% outliers
# LCLid MAC000153: 21.92% outliers
# LCLid MAC004230: 10.77% outliers
# LCLid MAC004549: 16.71% outliers
# LCLid MAC000046: 10.96% outliers
# LCLid MAC001951: 10.68% outliers
# LCLid MAC004956: 12.09% outliers
# LCLid MAC000170: 13.70% outliers
# LCLid MAC002422: 20.00% outliers
# LCLid MAC005425: 12.88% outliers
# LCLid MAC005464: 19.45% outliers
# LCLid MAC004605: 9.86% outliers
# LCLid MAC000601: 11.78% outliers
# LCLid MAC002371: 19.45% outliers
# LCLid MAC005016: 12.33% outliers
# LCLid MAC001124: 10.68% outliers
# LCLid MAC001842: 11.51% outliers
# LCLid MAC003047: 10.68% outliers
# LCLid MAC001494: 15.62% outliers
# LCLid MAC004062: 10.68% outliers
# LCLid MAC004282: 10.44% outliers
# LCLid MAC004488: 6.85% outliers
# LCLid MAC000608: 6.30% outliers
# LCLid MAC003569: 10.68% outliers
# LCLid MAC000244: 12.60% outliers
# LCLid MAC004882: 10.14% outliers
# LCLid MAC004813: 16.71% outliers
# LCLid MAC004815: 12.33% outliers
# LCLid MAC004930: 11.78% outliers
# LCLid MAC000191: 11.51% outliers
# LCLid MAC004217: 17.53% outliers
# LCLid MAC001599: 11.24% outliers
# LCLid MAC002022: 13.15% outliers
# LCLid MAC002383: 8.49% outliers
# LCLid MAC000045: 17.26% outliers
# LCLid MAC000066: 12.60% outliers
# LCLid MAC004025: 15.07% outliers
# LCLid MAC000051: 8.79% outliers
# LCLid MAC001733: 15.38% outliers
# LCLid MAC001453: 6.03% outliers
# LCLid MAC003954: 15.34% outliers
# LCLid MAC004159: 13.15% outliers
# LCLid MAC004838: 15.62% outliers
# LCLid MAC001655: 16.71% outliers
# LCLid MAC001687: 11.51% outliers
# LCLid MAC005306: 11.51% outliers
# LCLid MAC005399: 18.08% outliers
# LCLid MAC000411: 8.77% outliers
# LCLid MAC000856: 16.44% outliers
# LCLid MAC004133: 10.41% outliers
# LCLid MAC005000: 15.62% outliers
# LCLid MAC001040: 8.22% outliers
# LCLid MAC001330: 20.00% outliers
# LCLid MAC004325: 13.70% outliers
# LCLid MAC004327: 12.05% outliers
# LCLid MAC003396: 12.88% outliers
# LCLid MAC002949: 12.60% outliers
# LCLid MAC005138: 11.51% outliers
# LCLid MAC001588: 12.60% outliers
# LCLid MAC002224: 6.30% outliers
# LCLid MAC002306: 10.41% outliers
# LCLid MAC004643: 15.07% outliers
# LCLid MAC001221: 11.23% outliers
# LCLid MAC002063: 8.77% outliers
# LCLid MAC002765: 26.30% outliers
# LCLid MAC002931: 4.38% outliers
# LCLid MAC002624: 20.82% outliers
# LCLid MAC003858: 13.70% outliers
# LCLid MAC004983: 26.30% outliers
# LCLid MAC005485: 11.85% outliers
# LCLid MAC005089: 11.23% outliers
# LCLid MAC003004: 17.53% outliers
# LCLid MAC001901: 19.61% outliers
# LCLid MAC002169: 7.02% outliers
# LCLid MAC000289: 12.60% outliers
# LCLid MAC002218: 14.33% outliers
# LCLid MAC004628: 14.79% outliers
# LCLid MAC001338: 11.11% outliers
# LCLid MAC001578: 14.79% outliers
# LCLid MAC000293: 14.52% outliers
# LCLid MAC002365: 16.71% outliers
# LCLid MAC004542: 13.42% outliers
# LCLid MAC004651: 9.86% outliers
# LCLid MAC000299: 9.77% outliers
# LCLid MAC004600: 11.23% outliers
# LCLid MAC000356: 14.58% outliers
# LCLid MAC001498: 9.32% outliers
# LCLid MAC004855: 11.51% outliers
# LCLid MAC001925: 16.71% outliers
# LCLid MAC003669: 7.95% outliers
# LCLid MAC005065: 9.32% outliers
# LCLid MAC000944: 5.75% outliers
# LCLid MAC000953: 7.12% outliers
# LCLid MAC003079: 15.62% outliers
# LCLid MAC000288: 11.51% outliers
# LCLid MAC000826: 14.79% outliers
# LCLid MAC003928: 19.18% outliers
# LCLid MAC005255: 11.23% outliers
# LCLid MAC004587: 13.42% outliers
# LCLid MAC003883: 10.96% outliers
# LCLid MAC000287: 17.25% outliers
# LCLid MAC003005: 23.84% outliers
# LCLid MAC004194: 11.51% outliers
# LCLid MAC004266: 7.95% outliers
# LCLid MAC001769: 11.23% outliers
# LCLid MAC001906: 9.32% outliers
# LCLid MAC002655: 12.60% outliers
# LCLid MAC003222: 11.23% outliers
# LCLid MAC002209: 14.79% outliers
# LCLid MAC002294: 16.23% outliers
# LCLid MAC005545: 17.26% outliers
# LCLid MAC000451: 9.86% outliers
# LCLid MAC004279: 12.33% outliers
# LCLid MAC001368: 13.97% outliers
# LCLid MAC002682: 10.96% outliers
# LCLid MAC001029: 10.96% outliers
# LCLid MAC002281: 15.62% outliers
# LCLid MAC002324: 24.38% outliers
# LCLid MAC001112: 14.52% outliers
# LCLid MAC002877: 9.12% outliers
# LCLid MAC003046: 11.78% outliers
# LCLid MAC002045: 9.59% outliers
# LCLid MAC002146: 20.27% outliers
# LCLid MAC005288: 7.67% outliers
# LCLid MAC004400: 13.97% outliers
# LCLid MAC004399: 20.00% outliers
# LCLid MAC001559: 11.23% outliers
# LCLid MAC004639: 16.09% outliers
# LCLid MAC001997: 9.32% outliers
# LCLid MAC003800: 14.52% outliers
# LCLid MAC001660: 6.03% outliers
# LCLid MAC005167: 11.78% outliers
# LCLid MAC003502: 10.41% outliers
# LCLid MAC003264: 19.73% outliers
# LCLid MAC002305: 8.77% outliers
# LCLid MAC002382: 20.69% outliers
# LCLid MAC002896: 11.51% outliers
# LCLid MAC002615: 13.17% outliers
# LCLid MAC005256: 12.05% outliers
# LCLid MAC002290: 12.33% outliers
# LCLid MAC001512: 21.37% outliers
# LCLid MAC002350: 12.88% outliers
# LCLid MAC003890: 14.25% outliers
# LCLid MAC003066: 7.12% outliers
# LCLid MAC000961: 12.05% outliers
# LCLid MAC001907: 14.25% outliers
# LCLid MAC000515: 14.79% outliers
# LCLid MAC002257: 10.41% outliers
# LCLid MAC004646: 20.55% outliers
# LCLid MAC004739: 15.89% outliers
# LCLid MAC001869: 14.79% outliers
# LCLid MAC005349: 15.07% outliers
# LCLid MAC003721: 16.44% outliers
# LCLid MAC001775: 11.54% outliers
# LCLid MAC003207: 19.61% outliers
# LCLid MAC003376: 15.07% outliers
# LCLid MAC000729: 21.48% outliers
# LCLid MAC001416: 15.62% outliers
# LCLid MAC002904: 9.86% outliers
# LCLid MAC003643: 16.71% outliers
# LCLid MAC001768: 19.18% outliers
# LCLid MAC003709: 15.62% outliers
# LCLid MAC002892: 7.95% outliers
# LCLid MAC000272: 13.97% outliers
# LCLid MAC003000: 6.85% outliers
# LCLid MAC003208: 12.60% outliers
# LCLid MAC000236: 12.33% outliers
# LCLid MAC005381: 15.11% outliers
# LCLid MAC004675: 13.15% outliers
# LCLid MAC004886: 12.05% outliers
# LCLid MAC001696: 12.60% outliers
# LCLid MAC002731: 7.67% outliers
# LCLid MAC002603: 15.62% outliers
# LCLid MAC001668: 11.51% outliers
# LCLid MAC003054: 20.82% outliers
# LCLid MAC005118: 18.75% outliers
# LCLid MAC000898: 14.29% outliers
# LCLid MAC000924: 13.42% outliers
# LCLid MAC002297: 7.58% outliers
# LCLid MAC000468: 8.77% outliers
# LCLid MAC000479: 16.99% outliers
# LCLid MAC004732: 8.49% outliers
# LCLid MAC002375: 8.22% outliers
# LCLid MAC004016: 17.53% outliers
# LCLid MAC005324: 13.42% outliers
# LCLid MAC002981: 7.12% outliers
# LCLid MAC000213: 12.60% outliers
# LCLid MAC000363: 11.23% outliers
# LCLid MAC001762: 8.59% outliers
# LCLid MAC001943: 8.77% outliers
# LCLid MAC002186: 16.71% outliers
# LCLid MAC000193: 12.33% outliers
# LCLid MAC001425: 10.14% outliers
# LCLid MAC002782: 12.60% outliers
# LCLid MAC000862: 14.25% outliers
# LCLid MAC003261: 10.14% outliers
# LCLid MAC002270: 12.88% outliers
# LCLid MAC004895: 12.88% outliers
# LCLid MAC004899: 13.70% outliers
# LCLid MAC001248: 16.99% outliers
# LCLid MAC002301: 10.14% outliers
# LCLid MAC001113: 12.33% outliers
# LCLid MAC001844: 14.25% outliers
# LCLid MAC002001: 13.97% outliers
# LCLid MAC002003: 7.95% outliers
# LCLid MAC002107: 11.51% outliers
# LCLid MAC001068: 12.05% outliers
# LCLid MAC001423: 11.78% outliers
# LCLid MAC002442: 13.35% outliers
# LCLid MAC005428: 14.79% outliers
# LCLid MAC000799: 8.49% outliers
# LCLid MAC004396: 12.33% outliers
# LCLid MAC000531: 14.79% outliers
# LCLid MAC001235: 10.14% outliers
# LCLid MAC005211: 10.68% outliers
# LCLid MAC003180: 8.49% outliers
# LCLid MAC001704: 6.30% outliers
# LCLid MAC003317: 9.34% outliers
# LCLid MAC004349: 14.79% outliers
# LCLid MAC004746: 11.23% outliers
# LCLid MAC002987: 14.25% outliers
# LCLid MAC004389: 10.14% outliers
# LCLid MAC002657: 13.70% outliers
# LCLid MAC002196: 10.41% outliers
# LCLid MAC002298: 18.55% outliers
# LCLid MAC004711: 14.52% outliers
# LCLid MAC000263: 8.77% outliers
# LCLid MAC004557: 10.14% outliers
# LCLid MAC001187: 10.68% outliers
# LCLid MAC002823: 10.68% outliers
# LCLid MAC003052: 18.36% outliers
# LCLid MAC000759: 14.25% outliers
# LCLid MAC000801: 13.15% outliers
# LCLid MAC002255: 14.25% outliers
# LCLid MAC005423: 12.71% outliers
# LCLid MAC004726: 10.68% outliers
# LCLid MAC000322: 14.25% outliers
# LCLid MAC001764: 10.41% outliers
# LCLid MAC005208: 9.04% outliers
# LCLid MAC000647: 13.70% outliers
# LCLid MAC004386: 11.78% outliers
# LCLid MAC001681: 10.68% outliers
# LCLid MAC003188: 19.45% outliers
# LCLid MAC003195: 11.23% outliers
# LCLid MAC003279: 12.33% outliers
# LCLid MAC002325: 10.45% outliers
# LCLid MAC004222: 8.22% outliers
# LCLid MAC004885: 9.32% outliers
# LCLid MAC005196: 18.08% outliers
# LCLid MAC002769: 13.30% outliers
# LCLid MAC002608: 16.44% outliers
# LCLid MAC001130: 9.86% outliers
# LCLid MAC002806: 6.85% outliers
# LCLid MAC003919: 20.55% outliers
# LCLid MAC005055: 21.92% outliers
# LCLid MAC000708: 11.54% outliers
# LCLid MAC000810: 15.89% outliers
# LCLid MAC001318: 13.41% outliers
# LCLid MAC001343: 11.51% outliers
# LCLid MAC002139: 13.97% outliers
# LCLid MAC001986: 9.32% outliers
# LCLid MAC005144: 13.15% outliers
# LCLid MAC002250: 16.44% outliers
# LCLid MAC003791: 24.66% outliers
# LCLid MAC004314: 13.15% outliers
# LCLid MAC004076: 11.23% outliers
# LCLid MAC000169: 13.15% outliers
# LCLid MAC004352: 10.71% outliers
# LCLid MAC000732: 12.05% outliers
# LCLid MAC001246: 11.23% outliers
# LCLid MAC002843: 25.48% outliers
# LCLid MAC000899: 10.41% outliers
# LCLid MAC002923: 14.25% outliers
# LCLid MAC000305: 16.16% outliers
# LCLid MAC002258: 11.78% outliers
# LCLid MAC002632: 11.78% outliers
# LCLid MAC005547: 8.49% outliers
# LCLid MAC002925: 20.60% outliers
# LCLid MAC002651: 20.05% outliers
# LCLid MAC002636: 9.04% outliers
# LCLid MAC004274: 13.70% outliers
# LCLid MAC002336: 14.25% outliers
# LCLid MAC002413: 15.34% outliers
# LCLid MAC001658: 14.52% outliers
# LCLid MAC001909: 10.41% outliers
# LCLid MAC005561: 6.30% outliers
# LCLid MAC005044: 17.53% outliers
# LCLid MAC005088: 14.79% outliers
# LCLid MAC001413: 8.49% outliers
# LCLid MAC005553: 8.22% outliers
# LCLid MAC000783: 11.78% outliers
# LCLid MAC004688: 12.05% outliers
# LCLid MAC004193: 13.70% outliers
# LCLid MAC003877: 14.79% outliers
# LCLid MAC000929: 12.01% outliers
# LCLid MAC001468: 13.42% outliers
# LCLid MAC004195: 9.32% outliers
# LCLid MAC004252: 16.44% outliers
# LCLid MAC002560: 15.62% outliers
# LCLid MAC004765: 14.25% outliers
# LCLid MAC002181: 14.79% outliers
# LCLid MAC003063: 12.33% outliers
# LCLid MAC002484: 9.59% outliers
# LCLid MAC004742: 10.14% outliers
# LCLid MAC004878: 10.41% outliers
# LCLid MAC003002: 11.51% outliers
# LCLid MAC002276: 16.44% outliers
# LCLid MAC002642: 20.27% outliers
# LCLid MAC004710: 14.25% outliers
# LCLid MAC005305: 16.16% outliers
# LCLid MAC001504: 16.71% outliers
# LCLid MAC002953: 16.44% outliers
# LCLid MAC002972: 20.27% outliers
# LCLid MAC005041: 11.51% outliers
# LCLid MAC001061: 12.36% outliers
# LCLid MAC002861: 12.33% outliers
# LCLid MAC002469: 9.59% outliers
# LCLid MAC005442: 21.92% outliers
# LCLid MAC000167: 9.32% outliers
# LCLid MAC004175: 10.14% outliers
# LCLid MAC002153: 16.99% outliers
# LCLid MAC000584: 15.34% outliers
# LCLid MAC005049: 8.77% outliers
# LCLid MAC000116: 12.33% outliers
# LCLid MAC003845: 8.49% outliers
# LCLid MAC004221: 9.86% outliers
# LCLid MAC004351: 11.51% outliers
# LCLid MAC001367: 12.88% outliers
# LCLid MAC002944: 10.96% outliers
# LCLid MAC000130: 12.88% outliers
# LCLid MAC005168: 7.12% outliers
# LCLid MAC003171: 13.97% outliers
# LCLid MAC000583: 12.17% outliers
# LCLid MAC004277: 8.77% outliers
# LCLid MAC004642: 15.34% outliers
# LCLid MAC000264: 11.78% outliers
# LCLid MAC004891: 11.78% outliers
# LCLid MAC004907: 15.90% outliers
# LCLid MAC005214: 21.37% outliers
# LCLid MAC002635: 16.16% outliers
# LCLid MAC004691: 9.86% outliers
# LCLid MAC000679: 11.51% outliers
# LCLid MAC001457: 16.44% outliers
# LCLid MAC001461: 12.88% outliers
# LCLid MAC001469: 17.53% outliers
# LCLid MAC002226: 9.86% outliers
# LCLid MAC004827: 4.66% outliers
# LCLid MAC000115: 8.22% outliers
# LCLid MAC001307: 10.41% outliers
# LCLid MAC001341: 11.51% outliers
# LCLid MAC002955: 12.60% outliers
# LCLid MAC003049: 12.60% outliers
# LCLid MAC000298: 11.23% outliers
# LCLid MAC002447: 15.22% outliers
# LCLid MAC003937: 16.71% outliers
# LCLid MAC001420: 5.48% outliers
# LCLid MAC005224: 11.23% outliers
# LCLid MAC003214: 13.15% outliers
# LCLid MAC004506: 20.27% outliers
# LCLid MAC001887: 11.11% outliers
# LCLid MAC002734: 14.25% outliers
# LCLid MAC003136: 14.79% outliers
# LCLid MAC004873: 7.76% outliers
# LCLid MAC000182: 8.90% outliers
# LCLid MAC001903: 6.87% outliers
# LCLid MAC005170: 14.52% outliers
# LCLid MAC003018: 17.81% outliers
# LCLid MAC000802: 12.60% outliers
# LCLid MAC003077: 13.70% outliers
# LCLid MAC000408: 20.00% outliers
# LCLid MAC002206: 19.06% outliers
# LCLid MAC000259: 11.88% outliers
# LCLid MAC002602: 11.23% outliers
# LCLid MAC002694: 9.04% outliers
# LCLid MAC002951: 16.16% outliers
# LCLid MAC005330: 13.42% outliers
# LCLid MAC002570: 9.59% outliers
# LCLid MAC002611: 20.82% outliers
# LCLid MAC001499: 22.74% outliers
# LCLid MAC002265: 17.26% outliers
# ...
# LCLid MAC003270: 8.49% outliers
# LCLid MAC004812: 9.86% outliers
# LCLid MAC003774: 12.05% outliers
# LCLid MAC003484: 12.99% outliers
# LCLid MAC003538: 10.68% outliers
# LCLid MAC003645: 12.91% outliers
# LCLid MAC004117: 13.70% outliers
# LCLid MAC002563: 10.41% outliers
# LCLid MAC002601: 10.41% outliers
# LCLid MAC003098: 23.01% outliers
# LCLid MAC003147: 14.52% outliers
# LCLid MAC002477: 8.26% outliers
# LCLid MAC005533: 10.96% outliers
# LCLid MAC001175: 10.11% outliers
# LCLid MAC001693: 12.05% outliers
# LCLid MAC001731: 15.07% outliers
# LCLid MAC002165: 8.22% outliers
# LCLid MAC002172: 13.15% outliers
# LCLid MAC000338: 11.04% outliers
# LCLid MAC001852: 9.86% outliers
# LCLid MAC002322: 9.59% outliers
# LCLid MAC004480: 11.53% outliers
# LCLid MAC001779: 13.15% outliers
# LCLid MAC002108: 16.99% outliers
# LCLid MAC004924: 13.22% outliers
# LCLid MAC002121: 9.59% outliers
# LCLid MAC002142: 9.04% outliers
# LCLid MAC000559: 5.21% outliers
# LCLid MAC001586: 7.67% outliers
# LCLid MAC003316: 12.88% outliers
# LCLid MAC003703: 9.82% outliers
# LCLid MAC000624: 15.62% outliers
# LCLid MAC001182: 13.42% outliers
# LCLid MAC000885: 14.25% outliers
# LCLid MAC001259: 12.05% outliers
# LCLid MAC002540: 11.51% outliers
# LCLid MAC002714: 12.33% outliers
# LCLid MAC003892: 9.04% outliers
# LCLid MAC001291: 13.70% outliers
# LCLid MAC004558: 20.20% outliers
# LCLid MAC004037: 15.89% outliers
# LCLid MAC002815: 11.76% outliers
# LCLid MAC002835: 12.38% outliers
# LCLid MAC005257: 9.04% outliers
# LCLid MAC002407: 12.05% outliers
# LCLid MAC002498: 9.70% outliers
# LCLid MAC001711: 8.77% outliers
# LCLid MAC001808: 21.37% outliers
# LCLid MAC002647: 18.90% outliers
# LCLid MAC004010: 26.03% outliers
# LCLid MAC004649: 14.29% outliers
# LCLid MAC001556: 20.27% outliers
# LCLid MAC005504: 24.93% outliers
# LCLid MAC002727: 10.98% outliers
# LCLid MAC003310: 11.51% outliers
# LCLid MAC003783: 14.79% outliers
# LCLid MAC003425: 16.16% outliers
# LCLid MAC000135: 17.65% outliers
# LCLid MAC004425: 13.15% outliers
# LCLid MAC004824: 12.60% outliers
# LCLid MAC002920: 13.97% outliers
# LCLid MAC005187: 15.34% outliers
# LCLid MAC005234: 4.11% outliers
# LCLid MAC000902: 13.97% outliers
# LCLid MAC004964: 11.78% outliers
# LCLid MAC005025: 13.70% outliers
# LCLid MAC005514: 18.08% outliers
# LCLid MAC001223: 10.41% outliers
# LCLid MAC002971: 12.05% outliers
# LCLid MAC000628: 14.79% outliers
# LCLid MAC000822: 16.99% outliers
# LCLid MAC002096: 21.64% outliers
# LCLid MAC002180: 16.99% outliers
# LCLid MAC002204: 21.64% outliers
# LCLid MAC000088: 12.33% outliers
# LCLid MAC001256: 10.68% outliers
# LCLid MAC002352: 10.38% outliers
# LCLid MAC002353: 12.60% outliers
# LCLid MAC004672: 1.37% outliers
# LCLid MAC004470: 7.67% outliers
# LCLid MAC004474: 8.23% outliers
# LCLid MAC004511: 10.41% outliers
# LCLid MAC004518: 13.70% outliers
# LCLid MAC001431: 13.42% outliers
# LCLid MAC001557: 19.73% outliers
# LCLid MAC002118: 9.59% outliers
# LCLid MAC000506: 13.70% outliers
# LCLid MAC001142: 7.40% outliers
# LCLid MAC001576: 15.62% outliers
# LCLid MAC003827: 12.60% outliers
# LCLid MAC000052: 17.81% outliers
# LCLid MAC002148: 12.33% outliers
# LCLid MAC002555: 7.95% outliers
# LCLid MAC000308: 17.26% outliers
# LCLid MAC002643: 15.89% outliers
# LCLid MAC000490: 11.23% outliers
# LCLid MAC001669: 10.41% outliers
# LCLid MAC004513: 18.63% outliers
# LCLid MAC004122: 16.16% outliers
# LCLid MAC004912: 11.51% outliers
# LCLid MAC003011: 8.49% outliers
# LCLid MAC001628: 9.04% outliers
# LCLid MAC001893: 16.16% outliers
# LCLid MAC002150: 16.44% outliers
# LCLid MAC004940: 9.32% outliers
# LCLid MAC000312: 16.71% outliers
# LCLid MAC001854: 16.44% outliers
# LCLid MAC003992: 16.44% outliers
# LCLid MAC000165: 14.52% outliers
# LCLid MAC002011: 14.52% outliers
# LCLid MAC002040: 13.42% outliers
# LCLid MAC001564: 17.53% outliers
# LCLid MAC001788: 9.35% outliers
# LCLid MAC000118: 17.26% outliers
# LCLid MAC003333: 19.45% outliers
# LCLid MAC000716: 14.25% outliers
# LCLid MAC003491: 12.60% outliers
# LCLid MAC003289: 15.62% outliers
# LCLid MAC003291: 10.14% outliers
# LCLid MAC003510: 9.59% outliers
# LCLid MAC003660: 7.12% outliers
# LCLid MAC004721: 15.07% outliers
# LCLid MAC000404: 20.55% outliers
# LCLid MAC001936: 18.36% outliers
# LCLid MAC005171: 11.40% outliers
# LCLid MAC002235: 21.92% outliers
# LCLid MAC003186: 14.52% outliers
# LCLid MAC003248: 11.78% outliers
# LCLid MAC000528: 14.45% outliers
# LCLid MAC000626: 8.79% outliers
# LCLid MAC002406: 13.15% outliers
# LCLid MAC001105: 12.88% outliers
# LCLid MAC002068: 9.80% outliers
# LCLid MAC004986: 14.25% outliers
# LCLid MAC005018: 14.25% outliers
# LCLid MAC002434: 9.04% outliers
# LCLid MAC005418: 11.51% outliers
# LCLid MAC002930: 21.64% outliers
# LCLid MAC000544: 14.25% outliers
# LCLid MAC005413: 10.68% outliers
# LCLid MAC001598: 10.14% outliers
# LCLid MAC000495: 19.30% outliers
# LCLid MAC005321: 5.75% outliers
# LCLid MAC002701: 14.25% outliers
# LCLid MAC003909: 9.32% outliers
# LCLid MAC000422: 19.45% outliers
# LCLid MAC001850: 10.14% outliers
# LCLid MAC003546: 10.41% outliers
# LCLid MAC003983: 18.36% outliers
# LCLid MAC002914: 11.51% outliers
# LCLid MAC005235: 21.37% outliers
# LCLid MAC003114: 12.88% outliers
# LCLid MAC001181: 8.49% outliers
# LCLid MAC001723: 8.56% outliers
# LCLid MAC000482: 15.62% outliers
# LCLid MAC002168: 14.25% outliers
# LCLid MAC002333: 16.99% outliers
# LCLid MAC001596: 22.06% outliers
# LCLid MAC003244: 16.44% outliers
# LCLid MAC000863: 12.78% outliers
# LCLid MAC004916: 15.89% outliers
# LCLid MAC000712: 6.58% outliers
# LCLid MAC001597: 9.86% outliers
# LCLid MAC002151: 7.95% outliers
# LCLid MAC003640: 14.79% outliers
# LCLid MAC003706: 12.88% outliers
# LCLid MAC005011: 6.30% outliers
# LCLid MAC000824: 12.05% outliers
# LCLid MAC003343: 8.13% outliers
# LCLid MAC003356: 14.79% outliers
# LCLid MAC001937: 12.05% outliers
# LCLid MAC003886: 10.14% outliers
# LCLid MAC003978: 12.05% outliers
# LCLid MAC004577: 11.23% outliers
# LCLid MAC002807: 15.75% outliers
# LCLid MAC002628: 18.08% outliers
# LCLid MAC002937: 7.95% outliers
# LCLid MAC003166: 14.79% outliers
# LCLid MAC003113: 14.05% outliers
# LCLid MAC003158: 21.92% outliers
# LCLid MAC004963: 12.05% outliers
# LCLid MAC005479: 9.34% outliers
# LCLid MAC000864: 7.95% outliers
# LCLid MAC001832: 23.37% outliers
# LCLid MAC001851: 11.78% outliers
# LCLid MAC002326: 9.86% outliers
# LCLid MAC002361: 13.70% outliers
# LCLid MAC004496: 15.66% outliers
# LCLid MAC005555: 11.51% outliers
# LCLid MAC002236: 11.51% outliers
# LCLid MAC000488: 16.25% outliers
# LCLid MAC001360: 9.32% outliers
# LCLid MAC001632: 13.97% outliers
# LCLid MAC001780: 16.16% outliers
# LCLid MAC003531: 9.59% outliers
# LCLid MAC001638: 10.68% outliers
# LCLid MAC002005: 16.16% outliers
# LCLid MAC003326: 14.52% outliers
# LCLid MAC003496: 15.43% outliers
# LCLid MAC001202: 14.25% outliers
# LCLid MAC002673: 14.52% outliers
# LCLid MAC002992: 17.31% outliers
# LCLid MAC000922: 11.23% outliers
# LCLid MAC003072: 4.93% outliers
# LCLid MAC005455: 15.34% outliers
# LCLid MAC000024: 21.10% outliers
# LCLid MAC000831: 12.33% outliers
# LCLid MAC002935: 21.64% outliers
# LCLid MAC003068: 15.34% outliers
# LCLid MAC000525: 17.53% outliers
# LCLid MAC000458: 14.93% outliers
# LCLid MAC002173: 16.71% outliers
# LCLid MAC002341: 10.68% outliers
# LCLid MAC005267: 16.16% outliers
# LCLid MAC005470: 13.15% outliers
# LCLid MAC003266: 16.16% outliers
# LCLid MAC003276: 22.74% outliers
# LCLid MAC000871: 9.32% outliers
# LCLid MAC001873: 17.26% outliers
# LCLid MAC004677: 10.68% outliers
# LCLid MAC001323: 13.42% outliers
# LCLid MAC003765: 6.85% outliers
# LCLid MAC003918: 12.33% outliers
# LCLid MAC000389: 12.88% outliers
# LCLid MAC003245: 15.89% outliers
# LCLid MAC004047: 16.74% outliers
# LCLid MAC003664: 11.23% outliers
# LCLid MAC004039: 16.16% outliers
# LCLid MAC002831: 15.62% outliers
# LCLid MAC005183: 17.26% outliers
# LCLid MAC005220: 20.55% outliers
# LCLid MAC002952: 11.23% outliers
# LCLid MAC004172: 14.25% outliers
# LCLid MAC004040: 15.62% outliers
# LCLid MAC001519: 13.70% outliers
# LCLid MAC003306: 12.33% outliers
# LCLid MAC004256: 3.84% outliers
# LCLid MAC004455: 12.60% outliers
# LCLid MAC000351: 9.59% outliers
# LCLid MAC005497: 11.78% outliers
# LCLid MAC005521: 19.73% outliers
# LCLid MAC003405: 22.47% outliers
# LCLid MAC002954: 13.70% outliers
# LCLid MAC003287: 8.54% outliers
# LCLid MAC001541: 8.49% outliers
# LCLid MAC002654: 13.42% outliers
# LCLid MAC003320: 11.51% outliers
# LCLid MAC001397: 11.23% outliers
# LCLid MAC002373: 7.32% outliers
# LCLid MAC004406: 12.88% outliers
# LCLid MAC005502: 12.88% outliers
# LCLid MAC000239: 7.95% outliers
# LCLid MAC001045: 15.29% outliers
# LCLid MAC002669: 12.33% outliers
# LCLid MAC003294: 11.78% outliers
# LCLid MAC001017: 11.51% outliers
# LCLid MAC002758: 5.75% outliers
# LCLid MAC004414: 11.78% outliers
# LCLid MAC003584: 15.62% outliers
# LCLid MAC004925: 15.07% outliers
# LCLid MAC004989: 10.68% outliers
# LCLid MAC000663: 14.52% outliers
# LCLid MAC001562: 16.16% outliers
# LCLid MAC002421: 9.59% outliers
# LCLid MAC005505: 12.88% outliers
# LCLid MAC000294: 7.40% outliers
# LCLid MAC003284: 9.04% outliers
# LCLid MAC001683: 10.96% outliers
# LCLid MAC002703: 12.33% outliers
# LCLid MAC001532: 14.79% outliers
# LCLid MAC002039: 12.60% outliers
# LCLid MAC003397: 11.23% outliers
# LCLid MAC004447: 18.36% outliers
# LCLid MAC000080: 8.78% outliers
# LCLid MAC000654: 6.30% outliers
# LCLid MAC001571: 20.27% outliers
# LCLid MAC004921: 13.15% outliers
# LCLid MAC004977: 11.78% outliers
# LCLid MAC000773: 12.60% outliers
# LCLid MAC002788: 19.73% outliers
# LCLid MAC002844: 8.51% outliers
# LCLid MAC003375: 11.51% outliers
# LCLid MAC000566: 10.68% outliers
# LCLid MAC003076: 8.49% outliers
# LCLid MAC003413: 10.96% outliers
# LCLid MAC000353: 6.03% outliers
# LCLid MAC002704: 14.25% outliers
# LCLid MAC003041: 18.59% outliers
# LCLid MAC005476: 9.59% outliers
# LCLid MAC005512: 13.42% outliers
# LCLid MAC001982: 12.88% outliers
# LCLid MAC004662: 12.60% outliers
# LCLid MAC000017: 9.59% outliers
# LCLid MAC005506: 15.48% outliers
# LCLid MAC005532: 10.96% outliers
# LCLid MAC003292: 11.78% outliers
# LCLid MAC000811: 17.53% outliers
# LCLid MAC001309: 15.34% outliers
# LCLid MAC003162: 12.33% outliers
# LCLid MAC001671: 12.90% outliers
# LCLid MAC003850: 11.23% outliers
# LCLid MAC002154: 16.99% outliers
# LCLid MAC002164: 12.33% outliers
# LCLid MAC005552: 7.12% outliers
# LCLid MAC000995: 12.05% outliers
# LCLid MAC002763: 11.51% outliers
# LCLid MAC001581: 10.68% outliers
# LCLid MAC001326: 17.81% outliers
# LCLid MAC005409: 7.12% outliers
# LCLid MAC003275: 10.41% outliers
# LCLid MAC003639: 14.52% outliers
# LCLid MAC004937: 15.07% outliers
# LCLid MAC000251: 12.33% outliers
# LCLid MAC003293: 18.36% outliers
# LCLid MAC005484: 8.49% outliers
# LCLid MAC001993: 12.60% outliers
# LCLid MAC003061: 11.23% outliers
# LCLid MAC003755: 14.79% outliers
# LCLid MAC003933: 9.59% outliers
# LCLid MAC000639: 14.25% outliers
# LCLid MAC002131: 8.49% outliers
# LCLid MAC005496: 8.75% outliers
# LCLid MAC000800: 17.53% outliers
# LCLid MAC000343: 8.77% outliers
# LCLid MAC003149: 23.01% outliers
# LCLid MAC004717: 11.78% outliers
# LCLid MAC001537: 19.40% outliers
# LCLid MAC002631: 18.08% outliers
# LCLid MAC002688: 11.78% outliers
# LCLid MAC002822: 8.22% outliers
# LCLid MAC003408: 15.34% outliers
# LCLid MAC002295: 17.26% outliers
# LCLid MAC000581: 11.78% outliers
# LCLid MAC005461: 9.04% outliers
# LCLid MAC003642: 8.22% outliers
# LCLid MAC004336: 15.07% outliers
# LCLid MAC004369: 13.70% outliers
# LCLid MAC002721: 16.99% outliers
# LCLid MAC002291: 22.47% outliers
# LCLid MAC003048: 10.41% outliers
# LCLid MAC003381: 9.04% outliers
# LCLid MAC003651: 10.68% outliers
# LCLid MAC003927: 14.52% outliers
# LCLid MAC003278: 11.23% outliers
# LCLid MAC003299: 7.95% outliers
# LCLid MAC002098: 13.97% outliers
# LCLid MAC005539: 14.25% outliers
# LCLid MAC002766: 12.60% outliers
# LCLid MAC003282: 10.14% outliers
# LCLid MAC003837: 11.23% outliers
# LCLid MAC000651: 6.04% outliers
# LCLid MAC000938: 9.86% outliers
# LCLid MAC001212: 17.53% outliers
# LCLid MAC003412: 9.32% outliers
# LCLid MAC000646: 6.85% outliers
# LCLid MAC001522: 21.64% outliers
# LCLid MAC002156: 23.56% outliers
# LCLid MAC003323: 13.42% outliers
# LCLid MAC002262: 7.67% outliers
# LCLid MAC004141: 10.41% outliers
# LCLid MAC004200: 11.51% outliers
# LCLid MAC003231: 12.23% outliers
# LCLid MAC002828: 12.05% outliers
# LCLid MAC003330: 8.77% outliers
# LCLid MAC001796: 15.07% outliers
# LCLid MAC004810: 13.33% outliers
# LCLid MAC000598: 6.30% outliers
# LCLid MAC003748: 10.51% outliers
# LCLid MAC004108: 16.71% outliers
# LCLid MAC004504: 11.51% outliers
# LCLid MAC004585: 12.88% outliers
# LCLid MAC000078: 15.89% outliers
# LCLid MAC000355: 20.55% outliers
# LCLid MAC004772: 10.41% outliers
# LCLid MAC002797: 9.86% outliers
# LCLid MAC003283: 14.52% outliers
# LCLid MAC001513: 11.23% outliers
# LCLid MAC002140: 10.20% outliers
# LCLid MAC002280: 16.44% outliers
# LCLid MAC000081: 15.62% outliers
# LCLid MAC000401: 12.05% outliers
# LCLid MAC001026: 13.70% outliers
# LCLid MAC003492: 11.78% outliers
# LCLid MAC004164: 13.42% outliers
# LCLid MAC003907: 22.19% outliers
# LCLid MAC001516: 15.89% outliers
# LCLid MAC001526: 9.59% outliers
# LCLid MAC002658: 6.87% outliers
# LCLid MAC005530: 22.74% outliers
# LCLid MAC003420: 16.44% outliers
# LCLid MAC004407: 19.45% outliers
# LCLid MAC004367: 7.69% outliers
# LCLid MAC003340: 14.25% outliers
# LCLid MAC000532: 9.32% outliers
# LCLid MAC002031: 14.29% outliers
# LCLid MAC002785: 18.63% outliers
# LCLid MAC003913: 14.39% outliers
# LCLid MAC003923: 12.60% outliers
# LCLid MAC003592: 21.25% outliers
# LCLid MAC004415: 15.34% outliers
# LCLid MAC002132: 15.62% outliers
# LCLid MAC000254: 20.55% outliers
# LCLid MAC002749: 13.97% outliers
# LCLid MAC000623: 10.68% outliers
# LCLid MAC001286: 11.78% outliers
# LCLid MAC002664: 8.77% outliers
# LCLid MAC002848: 19.73% outliers
# LCLid MAC002871: 16.44% outliers
# LCLid MAC000013: 13.42% outliers
# LCLid MAC000761: 7.40% outliers
# LCLid MAC001336: 11.23% outliers
# LCLid MAC002742: 16.53% outliers
# LCLid MAC004853: 18.36% outliers
# LCLid MAC005518: 9.32% outliers
# LCLid MAC003260: 12.60% outliers
# LCLid MAC004029: 10.14% outliers
# LCLid MAC001517: 13.70% outliers
# LCLid MAC005491: 10.96% outliers
# LCLid MAC001666: 10.68% outliers
# LCLid MAC004763: 13.70% outliers
# LCLid MAC003235: 15.34% outliers
# LCLid MAC004664: 16.44% outliers
# LCLid MAC001044: 9.86% outliers
# LCLid MAC003314: 12.09% outliers
# LCLid MAC002778: 11.30% outliers
# LCLid MAC003647: 15.62% outliers
# LCLid MAC003288: 11.23% outliers
# LCLid MAC005028: 12.88% outliers
# LCLid MAC001009: 11.78% outliers
# LCLid MAC003322: 16.16% outliers
# LCLid MAC003406: 10.14% outliers
# LCLid MAC000872: 16.16% outliers
# LCLid MAC001085: 20.55% outliers
# LCLid MAC001486: 11.78% outliers
# LCLid MAC004240: 12.82% outliers
# LCLid MAC001435: 12.60% outliers
# LCLid MAC001643: 11.23% outliers
# LCLid MAC003776: 16.99% outliers
# LCLid MAC004932: 18.08% outliers
# LCLid MAC000751: 9.59% outliers
# LCLid MAC000881: 15.02% outliers
# LCLid MAC001178: 17.81% outliers
# LCLid MAC002415: 11.51% outliers
# LCLid MAC000652: 13.70% outliers
# LCLid MAC000669: 13.42% outliers
# LCLid MAC001534: 13.15% outliers
# LCLid MAC002099: 10.96% outliers
# LCLid MAC003382: 15.89% outliers
# LCLid MAC003389: 14.79% outliers
# LCLid MAC004241: 9.59% outliers
# LCLid MAC001727: 9.32% outliers
# LCLid MAC002612: 12.05% outliers
# LCLid MAC003395: 11.51% outliers
# LCLid MAC003384: 13.42% outliers
# LCLid MAC003313: 17.53% outliers
# LCLid MAC005509: 10.41% outliers
# LCLid MAC000637: 7.95% outliers
# LCLid MAC001521: 12.88% outliers
# LCLid MAC002102: 14.52% outliers
# LCLid MAC005526: 14.52% outliers
# LCLid MAC003404: 17.53% outliers
# LCLid MAC000734: 15.62% outliers
# LCLid MAC002961: 16.71% outliers
# LCLid MAC004464: 10.68% outliers
# LCLid MAC003731: 11.23% outliers
# LCLid MAC005490: 11.51% outliers
# LCLid MAC002106: 11.23% outliers
# LCLid MAC003421: 7.40% outliers
# LCLid MAC000005: 12.88% outliers
# LCLid MAC003787: 8.49% outliers
# LCLid MAC003912: 13.70% outliers
# LCLid MAC004926: 13.97% outliers
# LCLid MAC003354: 13.97% outliers
# LCLid MAC000195: 17.26% outliers
# LCLid MAC001506: 10.68% outliers
# LCLid MAC004965: 13.42% outliers
# LCLid MAC005531: 23.58% outliers
# LCLid MAC004673: 23.84% outliers
# LCLid MAC004712: 11.84% outliers
# LCLid MAC000012: 18.90% outliers
# LCLid MAC001572: 14.25% outliers
# LCLid MAC002726: 9.04% outliers
# LCLid MAC000381: 12.05% outliers
# LCLid MAC000016: 13.33% outliers
# LCLid MAC003939: 11.23% outliers
# LCLid MAC004750: 11.92% outliers
# LCLid MAC000349: 7.40% outliers

# %% [markdown]
# # DBSCAN clustering with Dataset A, output is dbscan_outliers

# %%
# Preprocessing: Drop rows with NaN values in the specified features
features = ['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']

# Aggregate data by LCLid (mean/median of daily usage data for each LCLid)
df_agg = dataset_A.groupby('LCLid')[features].agg(['mean', 'std', 'max', 'min']).reset_index()

# Flatten multi-level column names
df_agg.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in df_agg.columns]

# Standardize AFTER aggregation
scaler = StandardScaler()
df_agg.iloc[:, 1:] = scaler.fit_transform(df_agg.iloc[:, 1:])  # Exclude 'LCLid'

# Apply DBSCAN clustering across all LCLids
dbscan = DBSCAN(eps=7, min_samples=5)  # Tune eps and min_samples
df_agg['cluster'] = dbscan.fit_predict(df_agg.iloc[:, 1:])  # Exclude 'LCLid'

# Identify outliers (those labeled as -1 by DBSCAN)
dbscan_fraud_LCLid = df_agg[df_agg['cluster'] == -1]

# List of fraudulent LCLids, extract from dbscan_fraud_LCLid and store as python list
dbscan_outliers = dbscan_fraud_LCLid['LCLid_'].tolist()

print("Fraudulent LCLids:", dbscan_outliers)
# Out:
# Fraudulent LCLids: ['MAC000134', 'MAC000252', 'MAC000569', 'MAC000730', 'MAC001836', 'MAC002613', 'MAC002628', 'MAC002755', 'MAC002952', 'MAC003298', 'MAC003353', 'MAC003394', 'MAC003428', 'MAC003449', 'MAC004087', 'MAC004330', 'MAC004639', 'MAC004716', 'MAC004778', 'MAC005009', 'MAC005041', 'MAC005308', 'MAC005318', 'MAC005361']

# %% [markdown]
# # Step 7: Isolation forest with Dataset A, output is isolation_forest_outliers

# %%
# Select relevant features
features = ['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']

# Ensure dataset_A contains both features and LCLid_ before splitting
df_combined = dataset_A.copy()  # Make a copy to avoid modifying the original DataFrame

# Split into train (80%) and test (20%)
train_data, test_data = train_test_split(df_combined, test_size=0.2, random_state=42, shuffle=True)

# Train Isolation Forest model
model = IsolationForest(contamination=0.05, random_state=42)
train_data['Anomaly'] = model.fit_predict(train_data[features])

# Predict anomalies on test data
test_data['Anomaly'] = model.predict(test_data[features])

# Mark anomalies (-1 indicates anomaly, 1 indicates normal)
train_data['Anomaly'] = train_data['Anomaly'].map({1: 'Normal', -1: 'Anomaly'})
test_data['Anomaly'] = test_data['Anomaly'].map({1: 'Normal', -1: 'Anomaly'})

# Set the threshold for anomaly percentage 30% (any LCLid with 30% or more rows that is flag as anomaly will be flag as fraudulent)
threshold = 0.30

# Count total rows per LCLid and anomalies per LCLid
anomaly_counts = test_data.groupby('LCLid').agg(
    total_rows=('LCLid', 'size'),
    anomalies=('Anomaly', lambda x: (x == 'Anomaly').sum())
)

# Calculate the percentage of anomalies for each LCLid
anomaly_counts['anomaly_percentage'] = anomaly_counts['anomalies'] / anomaly_counts['total_rows']

# Flag LCLids as fraudulent if the percentage of anomalies exceeds the threshold
isolation_forest_outliers = anomaly_counts[anomaly_counts['anomaly_percentage'] >= threshold].index.tolist()

# Display fraudulent LCLids
print(len(isolation_forest_outliers))
# Out:
# 354

# %% [markdown]
# # Dataset B - Removing k_means_outliers, dbscan_outliers and  isolation_forest_outliers identified in earlier steps from Dataset A

# %%
# Combine all outliers into a single set for fast lookup
outliers_set = set(k_means_outliers + dbscan_outliers + isolation_forest_outliers)

# Drop rows from dataset_A where 'LCLid' is in the outliers set
dataset_B = dataset_A[~dataset_A['LCLid'].isin(outliers_set)]

# Display the filtered dataset
dataset_B.count()
# Out:
# LCLid            1699611
# day              1699611
# energy_median    1699611
# energy_mean      1699611
# energy_max       1699611
# energy_count     1699611
# energy_std       1699611
# energy_sum       1699611
# energy_min       1699611
# stdorToU         1699611
# Acorn            1699611
# Acorn_grouped    1699611
# file             1699611
# dtype: int64

# %% [markdown]
# # Load trained Auto-Encoder model and test on dataset_A, output is autoencoder_outliers

# %%
# Function to load and preprocess data
def load_and_preprocess_data(df):
    # Normalize features
    scaler = MinMaxScaler()
    df[['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']] = \
        scaler.fit_transform(df[['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']])
   
    return df, scaler

# Function to create sequences for training
def create_sequences(df, sequence_length=30):
    sequences, lcl_ids = [], []
    grouped = df.groupby('LCLid')
    
    for lcl_id, group in grouped:
        group = group.sort_values('day')
        data = group[['energy_median', 'energy_mean', 'energy_max', 'energy_count', 'energy_std', 'energy_sum', 'energy_min']].values
        
        for i in range(len(data) - sequence_length):
            sequences.append(data[i:i + sequence_length])
            lcl_ids.append(lcl_id)
    
    return np.array(sequences), np.array(lcl_ids)

# %%
# Load and preprocess dataset_B (training data)
df_train, scaler_train = load_and_preprocess_data(dataset_B)
X_train, lcl_train = create_sequences(df_train)

# Split dataset_B into training (80%) and validation (20%)
X_train, X_val, lcl_train, lcl_val = train_test_split(X_train, lcl_train, test_size=0.2, random_state=42, shuffle=False)

# %%
# Define S3 bucket and file path
s3_bucket = "459-team4-project"
s3_model_path = "models/autoencoder_model.h5"
local_model_path = "/tmp/autoencoder_model.h5"

# Download model from S3
s3 = boto3.client("s3")
s3.download_file(s3_bucket, s3_model_path, local_model_path)

# Load the model
autoencoder = tf.keras.models.load_model(local_model_path)

# Print model summary to verify loading
autoencoder.summary()
# Out:
# 2025-03-21 06:19:04.095246: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 30, 7)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 30, 64)         │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 30, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 30, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 30, 64)         │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_1 (Reshape)             │ (None, 1, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 1, 32)          │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 1, 64)          │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 1, 128)         │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 1, 64)          │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1, 7)           │           455 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 173,241 (676.73 KB)
#  Trainable params: 172,599 (674.21 KB)
#  Non-trainable params: 640 (2.50 KB)
#  Optimizer params: 2 (12.00 B)

# %%
# Load and preprocess dataset_A (test data)
df_test, scaler_test = load_and_preprocess_data(dataset_A)
X_test, lcl_test = create_sequences(df_test)

# Compute reconstruction error (MSE) on test data
reconstructed = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - reconstructed, 2), axis=(1, 2))  # Compute MSE per sequence

# Reconstruct training data to calculate the threshold
train_reconstructed = autoencoder.predict(X_train)
train_mse = np.mean(np.power(X_train - train_reconstructed, 2), axis=(1, 2))

# Set the fraud detection threshold (99th percentile of training MSE)
threshold = np.percentile(train_mse, 99)

# Predict and detect fraudulent LCLids
test_reconstructed = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - test_reconstructed, 2), axis=(1, 2))

# Identify fraudulent LCLids
fraud_mask = mse > threshold
autoencoder_outliers = set(lcl_test[fraud_mask])

print(f"Detected fraudulent LCLids: {autoencoder_outliers}")
# Out:
# 2025-03-21 06:19:15.640523: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1469891640 exceeds 10% of free system memory.
# 54684/54684 ━━━━━━━━━━━━━━━━━━━━ 345s 6ms/step
#    17/38881 ━━━━━━━━━━━━━━━━━━━━ 4:19 7ms/step
# 2025-03-21 06:25:48.940739: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1045112880 exceeds 10% of free system memory.
# 38881/38881 ━━━━━━━━━━━━━━━━━━━━ 245s 6ms/step
#    18/54684 ━━━━━━━━━━━━━━━━━━━━ 5:28 6ms/step
# 2025-03-21 06:30:28.868297: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1469891640 exceeds 10% of free system memory.
# 54684/54684 ━━━━━━━━━━━━━━━━━━━━ 344s 6ms/step
# Detected fraudulent LCLids: {'MAC005311', 'MAC001771', 'MAC002099', 'MAC001791', 'MAC002367', 'MAC004586', 'MAC003245', 'MAC001522', 'MAC002137', 'MAC001846', 'MAC000834', 'MAC003568', 'MAC001822', 'MAC004007', 'MAC003018', 'MAC004897', 'MAC003299', 'MAC001516', 'MAC005123', 'MAC002644', 'MAC005162', 'MAC002641', 'MAC001518', 'MAC004271', 'MAC003881', 'MAC005377', 'MAC001433', 'MAC004720', 'MAC001429', 'MAC002231', 'MAC004558', 'MAC004553', 'MAC003182', 'MAC003992', 'MAC002324', 'MAC002260', 'MAC000800', 'MAC000643', 'MAC003449', 'MAC004976', 'MAC000535', 'MAC005199', 'MAC005386', 'MAC003422', 'MAC003877', 'MAC000916', 'MAC004010', 'MAC002215', 'MAC001469', 'MAC004298', 'MAC004112', 'MAC002688', 'MAC001641', 'MAC004239', 'MAC005319', 'MAC002824', 'MAC003419', 'MAC005312', 'MAC001710', 'MAC001202', 'MAC004582', 'MAC000625', 'MAC003322', 'MAC005194', 'MAC004996', 'MAC001011', 'MAC002197', 'MAC001032', 'MAC003993', 'MAC003394', 'MAC005044', 'MAC001550', 'MAC004434', 'MAC005021', 'MAC000833', 'MAC001390', 'MAC001970', 'MAC005185', 'MAC005124', 'MAC003975', 'MAC001726', 'MAC002900', 'MAC005336', 'MAC000416', 'MAC001311', 'MAC001798', 'MAC003639', 'MAC000512', 'MAC005391', 'MAC001885', 'MAC005275', 'MAC001416', 'MAC003283', 'MAC002920', 'MAC005399', 'MAC004646', 'MAC000889', 'MAC002919', 'MAC005178', 'MAC002361', 'MAC001987', 'MAC002628', 'MAC005356', 'MAC004204', 'MAC004407', 'MAC004082', 'MAC001893', 'MAC004666', 'MAC004902', 'MAC000523', 'MAC005388', 'MAC000415', 'MAC004330', 'MAC003704', 'MAC005344', 'MAC005459', 'MAC004181', 'MAC003817', 'MAC005036', 'MAC003428', 'MAC005107', 'MAC003634', 'MAC003388', 'MAC003807', 'MAC001895', 'MAC000528', 'MAC000957', 'MAC002195', 'MAC002500', 'MAC004680', 'MAC002833', 'MAC004458', 'MAC001843', 'MAC000463', 'MAC001698', 'MAC000312', 'MAC004501', 'MAC000918', 'MAC000530', 'MAC005196', 'MAC001354', 'MAC000181', 'MAC001613', 'MAC004000', 'MAC004500', 'MAC001809', 'MAC005553', 'MAC003906', 'MAC000892', 'MAC001571', 'MAC005214', 'MAC001766', 'MAC000440', 'MAC001794', 'MAC001805', 'MAC001109', 'MAC002179', 'MAC004016', 'MAC000409', 'MAC004579', 'MAC004876', 'MAC005117', 'MAC005119', 'MAC002633', 'MAC000297', 'MAC004923', 'MAC001286', 'MAC005307', 'MAC002515', 'MAC000692', 'MAC005318', 'MAC001649', 'MAC000273', 'MAC005220', 'MAC003025', 'MAC004995', 'MAC003296', 'MAC003728', 'MAC001562', 'MAC004767', 'MAC005485', 'MAC004903', 'MAC004949', 'MAC001098', 'MAC001046', 'MAC000178', 'MAC003811', 'MAC004055', 'MAC000736', 'MAC001785', 'MAC005355', 'MAC003860', 'MAC000443', 'MAC002048', 'MAC003344', 'MAC004822', 'MAC004488', 'MAC004778', 'MAC002241', 'MAC001258', 'MAC005235', 'MAC004751', 'MAC003932', 'MAC001564', 'MAC000354', 'MAC000024', 'MAC004351', 'MAC004258', 'MAC000480', 'MAC005341', 'MAC001580', 'MAC003902', 'MAC005250', 'MAC001836', 'MAC003061', 'MAC004198', 'MAC004480', 'MAC005009', 'MAC004410', 'MAC004484', 'MAC005061', 'MAC005412', 'MAC002169', 'MAC001095', 'MAC000045', 'MAC003676', 'MAC004944', 'MAC002724', 'MAC005348', 'MAC004390', 'MAC004639', 'MAC002741', 'MAC005446', 'MAC004980', 'MAC004087', 'MAC005226', 'MAC002869', 'MAC000654', 'MAC005504', 'MAC005397', 'MAC004858', 'MAC005376', 'MAC005442', 'MAC002217', 'MAC002511', 'MAC000778', 'MAC003725', 'MAC005101', 'MAC001677', 'MAC001991', 'MAC002068', 'MAC000431', 'MAC004709', 'MAC003675', 'MAC000388', 'MAC004270', 'MAC001397', 'MAC004716', 'MAC004346', 'MAC002007', 'MAC004355', 'MAC002670', 'MAC004218', 'MAC004922', 'MAC004637', 'MAC002811', 'MAC001576', 'MAC002686', 'MAC005041', 'MAC004691', 'MAC000990', 'MAC003668', 'MAC000765', 'MAC000274', 'MAC000828', 'MAC001705', 'MAC002281', 'MAC004102', 'MAC003055', 'MAC003709', 'MAC003687', 'MAC000664', 'MAC002880', 'MAC002240', 'MAC002884', 'MAC004173', 'MAC000848', 'MAC004901', 'MAC000198', 'MAC004971', 'MAC003276', 'MAC005057', 'MAC000300', 'MAC000309', 'MAC002923', 'MAC003607', 'MAC002935', 'MAC004527', 'MAC005566', 'MAC004611', 'MAC005345', 'MAC002640', 'MAC000040', 'MAC000437', 'MAC001404', 'MAC00 ...

# %% [markdown]
# # Combining all the list of outliers

# %%
k_means_outliers = set(k_means_outliers)  # Convert list to set to remove duplicates
dbscan_outliers = set(dbscan_outliers)  # Convert list to set to remove duplicates
isolation_forest_outliers = set(isolation_forest_outliers)  # Convert list to set to remove duplicates
autoencoder_outliers = set(autoencoder_outliers)  # Convert list to set to remove duplicates

all_outliers = k_means_outliers | dbscan_outliers | isolation_forest_outliers | autoencoder_outliers

# %%
print(len(all_outliers))
# Out:
# 871

# %%
# Initialize dictionary for storing the results
outlier_dict = {}
unique_lclids_list = df['LCLid'].dropna().unique().tolist()

# Iterate through all LCLids in unique_lclids_list
for LCLid in unique_lclids_list:
    # Create an empty dictionary for this LCLid
    outlier_info = {}

    # Retrieve values from df based on LCLid
    LCLid_info = df[df['LCLid'] == LCLid][['Acorn', 'Acorn_grouped', 'file']].iloc[0]
    outlier_info['Acorn'] = LCLid_info['Acorn']
    outlier_info['Acorn_grouped'] = LCLid_info['Acorn_grouped']
    outlier_info['file'] = LCLid_info['file']

    # Check in which lists the LCLid is present
    flagged_by = []

    if LCLid in k_means_outliers:
        flagged_by.append('k_means')
    if LCLid in dbscan_outliers:
        flagged_by.append('dbscan')
    if LCLid in isolation_forest_outliers:
        flagged_by.append('isolation_forest')
    if LCLid in autoencoder_outliers:
        flagged_by.append('autoencoder')

    # If flagged by any method, add the list of flagging methods
    if flagged_by:
        outlier_info['flagged_by'] = flagged_by
    else:
        outlier_info['flagged_by'] = []

    # Add the LCLid entry to the outlier_dict
    outlier_dict[LCLid] = outlier_info

# Print the dictionary for a sample LCLid
print(outlier_dict.get(list(outlier_dict.keys())[0]))  # Printing details of the first LCLid
# Out:
# {'Acorn': 'ACORN-E', 'Acorn_grouped': 'Affluent', 'file': 'block_22', 'flagged_by': []}

# %% [markdown]
# # Exporting the Outliers info as a CSV

# %%
import pandas as pd
import boto3
from botocore.exceptions import NoCredentialsError

# Convert outlier_dict to a list of dictionaries for pandas
outlier_list = []

for LCLid, info in outlier_dict.items():
    # Create a dictionary for each LCLid with its values
    LCLid_info = {
        'LCLid': LCLid,
        'acorn': info['Acorn'],
        'acorn_grouped': info['Acorn_grouped'],
        'file': info['file'],
        'flagged_by': ', '.join(info['flagged_by'])  # Join list into a string
    }
    outlier_list.append(LCLid_info)

# Convert the list of dictionaries into a pandas DataFrame
outlier_df = pd.DataFrame(outlier_list)

# Export the DataFrame to a CSV file locally
outlier_df.to_csv('output_q1.csv', index=False)

print("Outlier dictionary exported to 'output_q1.csv'")

# Upload the file to S3
s3_bucket_name = '459-team4-project'
s3_folder_path = 'notebook_output_q1/output_q1.csv'

# Initialize a session using Amazon S3
s3_client = boto3.client('s3')

try:
    # Upload the file
    s3_client.upload_file('output_q1.csv', s3_bucket_name, s3_folder_path)
    print(f"File successfully uploaded to s3://{s3_bucket_name}/{s3_folder_path}")
except NoCredentialsError:
    print("Credentials not available.")
except Exception as e:
    print(f"Error uploading file: {e}")
# Out:
# Outlier dictionary exported to 'output_q1.csv'
# File successfully uploaded to s3://459-team4-project/notebook_output_q1/output_q1.csv
